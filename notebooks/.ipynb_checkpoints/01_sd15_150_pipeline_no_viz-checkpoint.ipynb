# %% [markdown]
# # 01 — SD 1.5 pipeline: 150 samples, no vis

# %%
from pathlib import Path
import os
import sys
import json
import shutil
import subprocess
from datetime import datetime

import pandas as pd
from IPython.display import display


def looks_like_repo(path: Path) -> bool:
    return (path / "src").exists() and (path / "configs").exists()


cwd = Path.cwd().resolve()
repo_candidates = [cwd, *cwd.parents]
repo_candidates += [
    Path("/home/jupyter/project/diffusion_attention_analysis_2"),
    Path("/home/jupyter/datasphere/project/diffusion_attention_analysis_2"),
    Path("/mnt/data/diffzip/diffusion_attention_analysis_v2"),
]

PROJECT_ROOT = next((p.resolve() for p in repo_candidates if looks_like_repo(p)), None)
if PROJECT_ROOT is None:
    raise FileNotFoundError(
        "Cannot locate diffusion_attention_analysis_2 repository. "
        "Run this notebook from the repo root or from repo/notebooks."
    )

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.environ["PYTHONPATH"] = str(PROJECT_ROOT / "src") + os.pathsep + os.environ.get("PYTHONPATH", "")

from diffusion_attention_analysis_v2.notebook_runner import run_config, show_report

print("PROJECT_ROOT =", PROJECT_ROOT)
print("Python =", sys.executable)
print("cwd =", Path.cwd())
# Out:
# PROJECT_ROOT = /home/jupyter/project/diffusion_attention_analysis_2
# Python = /usr/local/bin/python3
# cwd = /home/jupyter/project/diffusion_attention_analysis_2

# %% [markdown]
# ## 0.1 Path management: `project` vs `container2`

# %%
STORAGE_CANDIDATES = [
    Path("/home/jupyter/datasphere/filestore/container2"),
    Path("/home/jupyter/filestore/container2"),
    Path("/filestore/container2"),
]

STORAGE = next((p.resolve() for p in STORAGE_CANDIDATES if p.exists()), None)
if STORAGE is None:
    raise FileNotFoundError(
        "Cannot find filestore/container2. Checked: " + ", ".join(map(str, STORAGE_CANDIDATES))
    )

STORAGE_PROJECT = STORAGE / PROJECT_ROOT.name
STORAGE_PROJECT.mkdir(parents=True, exist_ok=True)

# HuggingFace / torch / tmp caches stay in container2, not in project.
HF_HOME = STORAGE / "hf_home"
HF_HUB_CACHE = HF_HOME / "hub"
HF_DATASETS_CACHE = HF_HOME / "datasets"
HF_XET_CACHE = HF_HOME / "xet"
TORCH_HOME = STORAGE / "torch_home"
TMPDIR = STORAGE / "tmp"
PIP_CACHE_DIR = STORAGE / "pip_cache"

for p in [HF_HOME, HF_HUB_CACHE, HF_DATASETS_CACHE, HF_XET_CACHE, TORCH_HOME, TMPDIR, PIP_CACHE_DIR]:
    p.mkdir(parents=True, exist_ok=True)

os.environ.update({
    "HF_HOME": str(HF_HOME),
    "HF_HUB_CACHE": str(HF_HUB_CACHE),
    "HUGGINGFACE_HUB_CACHE": str(HF_HUB_CACHE),
    "HF_DATASETS_CACHE": str(HF_DATASETS_CACHE),
    "HF_XET_CACHE": str(HF_XET_CACHE),
    "TORCH_HOME": str(TORCH_HOME),
    "TMPDIR": str(TMPDIR),
    "TEMP": str(TMPDIR),
    "TMP": str(TMPDIR),
    "PIP_CACHE_DIR": str(PIP_CACHE_DIR),
    "HF_HUB_DISABLE_XET": "1",
})
os.environ.pop("TRANSFORMERS_CACHE", None)
os.environ.pop("DIFFUSERS_CACHE", None)

print("STORAGE =", STORAGE)
print("STORAGE_PROJECT =", STORAGE_PROJECT)
print("HF_HOME =", os.environ["HF_HOME"])
print("TMPDIR =", os.environ["TMPDIR"])
subprocess.run(["df", "-h", str(PROJECT_ROOT), str(STORAGE)], check=False)
# Out:
# STORAGE = /home/jupyter/filestore/container2
# STORAGE_PROJECT = /home/jupyter/filestore/container2/diffusion_attention_analysis_2
# HF_HOME = /home/jupyter/filestore/container2/hf_home
# TMPDIR = /home/jupyter/filestore/container2/tmp
# Filesystem            Size  Used Avail Use% Mounted on
# fhm183neaece9stlafd4   10G  5.0G  5.1G  50% /home/jupyter
# fhmof5starkethtouvhk   30G  8.4G   22G  28% /home/jupyter/filestore/container2
# CompletedProcess(args=['df', '-h', '/home/jupyter/project/diffusion_attention_analysis_2', '/home/jupyter/filestore/container2'], returncode=0)

# %%
LINK_LARGE_DIRS = True
LARGE_DIRS = ["outputs", "annotations", "checkpoints", "runs"]


def copy_dir_contents(src: Path, dst: Path) -> None:
    dst.mkdir(parents=True, exist_ok=True)
    if any(src.iterdir()):
        if shutil.which("rsync"):
            subprocess.run(["rsync", "-a", f"{src}/", f"{dst}/"], check=True)
        else:
            shutil.copytree(src, dst, dirs_exist_ok=True)


def unique_backup_path(path: Path) -> Path:
    base = path.with_name(path.name + ".project_backup")
    if not base.exists():
        return base
    stamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    return path.with_name(path.name + f".project_backup.{stamp}")


def ensure_storage_symlink(name: str) -> None:
    project_path = PROJECT_ROOT / name
    storage_path = STORAGE_PROJECT / name
    storage_path.mkdir(parents=True, exist_ok=True)

    if project_path.is_symlink():
        print(f"{name}: already symlink -> {project_path.resolve()}")
        return

    if project_path.exists():
        if not project_path.is_dir():
            raise RuntimeError(f"{project_path} exists and is not a directory")
        copy_dir_contents(project_path, storage_path)
        backup = unique_backup_path(project_path)
        project_path.rename(backup)
        project_path.symlink_to(storage_path, target_is_directory=True)
        print(f"{name}: moved project dir to {backup.name}; symlink -> {storage_path}")
    else:
        project_path.symlink_to(storage_path, target_is_directory=True)
        print(f"{name}: symlink -> {storage_path}")


if LINK_LARGE_DIRS:
    for dirname in LARGE_DIRS:
        ensure_storage_symlink(dirname)

print("\nResolved large dirs:")
for dirname in LARGE_DIRS:
    p = PROJECT_ROOT / dirname
    print(f"{dirname:12s}", "->", p.resolve() if p.exists() else "missing")
# Out:
# outputs: already symlink -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/outputs
# annotations: already symlink -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/annotations
# checkpoints: already symlink -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/checkpoints
# runs: already symlink -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/runs
#
# Resolved large dirs:
# outputs      -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/outputs
# annotations  -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/annotations
# checkpoints  -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/checkpoints
# runs         -> /home/jupyter/filestore/container2/diffusion_attention_analysis_2/runs

# %%
INSTALL_DEPS = False

if INSTALL_DEPS:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "huggingface_hub>=0.26.0"])
    subprocess.check_call([sys.executable, "-m", "pip", "install", "diffusers==0.29.0", "transformers==4.40.0", "accelerate", "safetensors"])
    

try:
    import torch
    print("torch:", torch.__version__, "cuda:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("gpu:", torch.cuda.get_device_name(0))
except Exception as exc:
    print("torch import failed:", exc)

if shutil.which("nvidia-smi"):
    subprocess.run(["nvidia-smi"], check=False)
else:
    print("nvidia-smi not found")
# Out:
# torch: 2.2.0+cu121 cuda: True
# gpu: Tesla V100-PCIE-32GB
# Sun May 10 19:53:25 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.261.03             Driver Version: 535.261.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-32GB           On  | 00000000:81:00.0 Off |                  Off |
# | N/A   27C    P0              24W / 250W |      8MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A       844      G   /usr/lib/xorg/Xorg                            4MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 0.3 Experiment settings

# %%
SMOKE_TEST = False
RUN_DRY_RUNS = True
RUN_ACTUAL_STAGES = True

TARGET_SAMPLES = 150
NUM_SEEDS = 1
NUM_PROMPTS = TARGET_SAMPLES // NUM_SEEDS

if SMOKE_TEST:
    RUN_TAG = "sd15_150_smoke"
    NUM_PROMPTS = 8
    NUM_SEEDS = 1
else:
    RUN_TAG = "sd15_150"

assert NUM_PROMPTS * NUM_SEEDS == (8 if SMOKE_TEST else TARGET_SAMPLES)

PROMPTS_150 = PROJECT_ROOT / "prompts/sd15_150_prompts.jsonl"
INTERVENTION_PROMPTS_150 = PROJECT_ROOT / "prompts/sd15_150_intervention_prompts.jsonl"

CAPTURE_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/01_capture"
MASK_DIR = PROJECT_ROOT / f"annotations/{RUN_TAG}"
LOC_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/02_attention_localization"
SAE_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/03_sae_mid"
CONCEPT_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/04_concept_dictionary"
MAP_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/05_intervention_map_reweight"
SAE_STEER_DIR = PROJECT_ROOT / f"outputs/{RUN_TAG}/05_intervention_sae_steering"

print("RUN_TAG:", RUN_TAG)
print("NUM_PROMPTS:", NUM_PROMPTS)
print("NUM_SEEDS:", NUM_SEEDS)
print("target samples:", NUM_PROMPTS * NUM_SEEDS)
print("outputs resolved:", (PROJECT_ROOT / "outputs").resolve())
print("annotations resolved:", (PROJECT_ROOT / "annotations").resolve())
# Out:
# RUN_TAG: sd15_150
# NUM_PROMPTS: 150
# NUM_SEEDS: 1
# target samples: 150
# outputs resolved: /home/jupyter/filestore/container2/diffusion_attention_analysis_2/outputs
# annotations resolved: /home/jupyter/filestore/container2/diffusion_attention_analysis_2/annotations

# %%
RESET_RUN = False

if RESET_RUN:
    for p in [CAPTURE_DIR, MASK_DIR, LOC_DIR, SAE_DIR, CONCEPT_DIR, MAP_DIR, SAE_STEER_DIR]:
        if p.exists() or p.is_symlink():
            print("Removing", p)
            shutil.rmtree(p, ignore_errors=True)

# %% [markdown]
# ## 0.4 Curated 150-prompt set

# %%
base_specs = [
    ("dog", "grass", "a dog standing on green grass", ["dog", "grass"]),
    ("car", "street", "a red car on a city street", ["car", "street"]),
    ("cat", "chair", "a cat sitting on a wooden chair", ["cat", "chair"]),
    ("dog", "bicycle", "a dog next to a bicycle", ["dog", "bicycle"]),
    ("cup", "book", "a cup to the left of a book", ["cup", "book"]),
    ("vase", "flower", "a blue vase with yellow flowers", ["vase", "flower"]),
    ("person", "umbrella", "a person holding an umbrella in the rain", ["person", "umbrella"]),
    ("robot", "bench", "a small robot reading a newspaper on a bench", ["robot", "newspaper", "bench"]),
    ("bicycle", "tree", "a bicycle leaning against a tree", ["bicycle", "tree"]),
    ("dog", "bench", "a dog sitting on a park bench", ["dog", "bench"]),
    ("cat", "book", "a cat lying next to an open book", ["cat", "book"]),
    ("cup", "table", "a white cup on a wooden table", ["cup", "table"]),
    ("flower", "grass", "yellow flowers growing in green grass", ["flower", "grass"]),
    ("person", "dog", "a person walking a dog on the street", ["person", "dog", "street"]),
    ("robot", "cup", "a robot holding a cup in a kitchen", ["robot", "cup"]),
    ("car", "umbrella", "a car near a person with an umbrella", ["car", "person", "umbrella"]),
    ("vase", "table", "a ceramic vase on a small table", ["vase", "table"]),
    ("book", "chair", "a book resting on a chair", ["book", "chair"]),
    ("cat", "flower", "a cat sitting on grass near flowers", ["cat", "grass", "flower"]),
    ("bicycle", "street", "a bicycle on a quiet city street", ["bicycle", "street"]),
    ("dog", "tree", "a dog standing under a tree", ["dog", "tree"]),
    ("newspaper", "bench", "a newspaper lying on a bench", ["newspaper", "bench"]),
    ("cup", "flower", "a cup beside flowers on a table", ["cup", "flower", "table"]),
    ("person", "bicycle", "a person standing beside a bicycle", ["person", "bicycle"]),
    ("apple", "basket", "a red apple in a woven basket", ["apple", "basket"]),
    ("banana", "bowl", "a banana in a ceramic bowl", ["banana", "bowl"]),
    ("laptop", "desk", "a laptop computer on a desk", ["laptop", "desk"]),
    ("phone", "book", "a phone placed next to a book", ["phone", "book"]),
    ("bird", "tree", "a bird perched on a tree branch", ["bird", "tree"]),
    ("boat", "river", "a small boat floating on a river", ["boat", "river"]),
    ("bus", "street", "a yellow bus on a city street", ["bus", "street"]),
    ("train", "station", "a train stopped at a station", ["train", "station"]),
    ("airplane", "sky", "an airplane flying in the blue sky", ["airplane", "sky"]),
    ("horse", "field", "a horse standing in a field", ["horse", "field"]),
    ("pizza", "plate", "a slice of pizza on a plate", ["pizza", "plate"]),
    ("bottle", "table", "a glass bottle on a table", ["bottle", "table"]),
    ("clock", "wall", "a round clock hanging on a wall", ["clock", "wall"]),
    ("backpack", "chair", "a backpack hanging from a chair", ["backpack", "chair"]),
    ("skateboard", "sidewalk", "a skateboard on a concrete sidewalk", ["skateboard", "sidewalk"]),
    ("bridge", "river", "a bridge crossing a wide river", ["bridge", "river"]),
    ("mountain", "lake", "a mountain reflected in a lake", ["mountain", "lake"]),
    ("building", "window", "a tall building with many windows", ["building", "window"]),
    ("door", "hallway", "a wooden door at the end of a hallway", ["door", "hallway"]),
    ("hat", "table", "a hat lying on a table", ["hat", "table"]),
    ("shoes", "floor", "a pair of shoes on the floor", ["shoes", "floor"]),
    ("teddy_bear", "bed", "a teddy bear sitting on a bed", ["bear", "bed"]),
    ("camera", "tripod", "a camera mounted on a tripod", ["camera", "tripod"]),
    ("candle", "shelf", "a candle standing on a shelf", ["candle", "shelf"]),
    ("fish", "bowl", "a fish swimming in a glass bowl", ["fish", "bowl"]),
    ("plant", "window", "a green plant near a window", ["plant", "window"]),
]

variants = [
    ("photo", "a photo of {scene}"),
    ("clear", "a clear image of {scene}"),
    ("detailed", "a detailed scene with {scene}"),
]

records = []
for base_idx, (slug_a, slug_b, scene, labels) in enumerate(base_specs, start=1):
    for variant_key, template in variants:
        idx = len(records) + 1
        prompt = template.format(scene=scene)
        entities = [{"label": label, "token": label} for label in labels]
        records.append({
            "id": f"s150_{idx:03d}_{slug_a}_{slug_b}_{variant_key}",
            "prompt": prompt,
            "entities": entities,
        })

assert len(records) == 150, len(records)

PROJECT_ROOT.joinpath("prompts").mkdir(parents=True, exist_ok=True)
with PROMPTS_150.open("w", encoding="utf-8") as f:
    for row in records:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

quadrants = ["top_left", "top_right", "bottom_left", "bottom_right"]
intervention_records = []
for i, row in enumerate(records):
    target_word = row["entities"][0]["token"]
    item = dict(row)
    item["target_word"] = target_word
    item["quadrant"] = quadrants[i % len(quadrants)]
    intervention_records.append(item)

with INTERVENTION_PROMPTS_150.open("w", encoding="utf-8") as f:
    for row in intervention_records:
        f.write(json.dumps(row, ensure_ascii=False) + "\n")

print("Wrote:", PROMPTS_150, "rows=", len(records))
print("Wrote:", INTERVENTION_PROMPTS_150, "rows=", len(intervention_records))
display(pd.DataFrame(records).head(8))
# Out:
# Wrote: /home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_prompts.jsonl rows= 150
# Wrote: /home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_intervention_prompts.jsonl rows= 150
#                              id  ...                                           entities
# 0      s150_001_dog_grass_photo  ...  [{'label': 'dog', 'token': 'dog'}, {'label': '...
# 1      s150_002_dog_grass_clear  ...  [{'label': 'dog', 'token': 'dog'}, {'label': '...
# 2   s150_003_dog_grass_detailed  ...  [{'label': 'dog', 'token': 'dog'}, {'label': '...
# 3     s150_004_car_street_photo  ...  [{'label': 'car', 'token': 'car'}, {'label': '...
# 4     s150_005_car_street_clear  ...  [{'label': 'car', 'token': 'car'}, {'label': '...
# 5  s150_006_car_street_detailed  ...  [{'label': 'car', 'token': 'car'}, {'label': '...
# 6      s150_007_cat_chair_photo  ...  [{'label': 'cat', 'token': 'cat'}, {'label': '...
# 7      s150_008_cat_chair_clear  ...  [{'label': 'cat', 'token': 'cat'}, {'label': '...
#
# [8 rows x 3 columns]

# %% [markdown]
# ## Stage 1 — capture

# %%
CAPTURE_OVERRIDES = [
    f"data.prompts_path={PROMPTS_150}",
    f"data.output_dir={CAPTURE_DIR}",
    f"data.max_prompts={NUM_PROMPTS}",
    "runtime.seed_start=0",
    f"runtime.num_seeds={NUM_SEEDS}",
    "capture.save_latents=false",
]

if RUN_DRY_RUNS:
    run_config("configs/01_capture/sd15_full.yaml", overrides=CAPTURE_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/01_capture/sd15_full.yaml", overrides=CAPTURE_OVERRIDES)
    show_report(str(CAPTURE_DIR / "report.json"))
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sd15_full.yaml --dry-run --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_prompts.jsonl --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override capture.save_latents=false
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sd15_full.yaml --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_prompts.jsonl --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override capture.save_latents=false
# 2026-05-10 19:56:01.063432: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:20: FutureWarning: `VQEncoderOutput` is deprecated and will be removed in version 0.31. Importing `VQEncoderOutput` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQEncoderOutput`, instead.
#   deprecate("VQEncoderOutput", "0.31", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:25: FutureWarning: `VQModel` is deprecated and will be removed in version 0.31. Importing `VQModel` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQModel`, instead.
#   deprecate("VQModel", "0.31", deprecation_message)
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  14%|█▍        | 1/7 [00:02<00:13,  2.25s/it]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:22<01:03, 12.65s/it]
# Loading pipeline components...:  43%|████▎     | 3/7 [00:22<00:27,  6.99s/it]
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:26<00:17,  5.68s/it]
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:27<00:08,  4.22s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:27<00:00,  3.97s/it]
# capture started:   0%|          | 0/150 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:02<01:46,  2.18s/it]
#   6%|▌         | 3/50 [00:02<00:28,  1.63it/s]
#  10%|█         | 5/50 [00:02<00:15,  2.99it/s]
#  14%|█▍        | 7/50 [00:02<00:09,  4.55it/s]
#  18%|█▊        | 9/50 [00:02<00:06,  6.21it/s]
#  22%|██▏       | 11/50 [00:02<00:04,  7.82it/s]
#  26%|██▌       | 13/50 [00:02<00:03,  9.36it/s]
#  30%|███       | 15/50 [00:03<00:03, 10.66it/s]
#  34%|███▍      | 17/50 [00:03<00:02, 11.82it/s]
#  38%|███▊      | 19/50 [00:03<00:02, 12.79it/s]
#  42%|████▏     | 21/50 [00:03<00:02, 13.55it/s]
#  46%|████▌     | 23/50 [00:03<00:01, 13.93it/s]
#  50%|█████     | 25/50 [00:03<00:02, 11.03it/s]
#  54%|█████▍    | 27/50 [00:04<00:01, 12.13it/s]
#  58%|█████▊    | 29/50 [00:04<00:01, 13.04it/s]
#  62%|██████▏   | 31/50 [00:04<00:01, 13.76it/s]
#  66%|██████▌   | 33/50 [00:04<00:01, 14.34it/s]
#  70%|███████   | 35/50 [00:04<00:01, 14.72it/s]
#  74%|███████▍  | 37/50 [00:04<00:00, 14.94it/s]
#  78%|███████▊  | 39/50 [00:04<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:04<00:00, 15.26it/s]
#  86%|████████▌ | 43/50 [00:05<00:00, 15.34it/s]
#  90%|█████████ | 45/50 [00:05<00:00, 15.38it/s]
#  94%|█████████▍| 47/50 [00:05<00:00, 15.35it/s]
#  98%|█████████▊| 49/50 [00:05<00:00, 15.44it/s]
# 100%|██████████| 50/50 [00:05<00:00,  8.86it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 72.058, 'total': 150, 'current': 1, 'sample_id': 's150_001_dog_grass_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.38it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.07it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.73it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.38it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.43it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.11it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.56it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.90it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.12it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.27it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.35it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.44it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.11it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.16it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.03it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.61it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.17it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.60it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.84it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.10it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.25it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.38it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.50it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.44it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.50it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.28it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 76.088, 'total': 150, 'current': 2, 'sample_id': 's150_002_dog_grass_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.53it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.26it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.90it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.53it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.51it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.16it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.55it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.89it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.31it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.38it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.58it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.52it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.33it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.85it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.31it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.70it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.97it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.21it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.29it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.34it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.29it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.41it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.41it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 80.08, 'total': 150, 'current': 3, 'sample_id': 's150_003_dog_grass_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.59it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.38it/s]
#  10%|█         | 5/50 [00:00<00:04, 11.03it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.68it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.65it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.29it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.54it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.78it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.01it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.08it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.21it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.33it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.52it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 11.65it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.61it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.30it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 13.87it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.30it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.65it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.89it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.08it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.24it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.33it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.36it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.37it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.12it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 84.201, 'total': 150, 'current': 4, 'sample_id': 's150_004_car_street_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.26it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.85it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.53it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.17it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.25it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.92it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.41it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.75it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.99it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.13it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.25it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.32it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.88it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 11.96it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.82it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.08it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.46it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.78it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.97it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.02it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 14.82it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 14.98it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.11it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.26it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.08it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 88.326, 'total': 150, 'current': 5, 'sample_id': 's150_005_car_street_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.20it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.81it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.50it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.18it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.29it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.05it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.49it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.82it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.04it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.23it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.32it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.38it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.38it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.36it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.17it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.83it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.33it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.68it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.89it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.06it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.20it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.33it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.50it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.53it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.27it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 92.389, 'total': 150, 'current': 6, 'sample_id': 's150_006_car_street_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.37it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.02it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.69it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.34it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.36it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.06it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.50it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.65it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.91it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.11it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.28it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.33it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.47it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.37it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.18it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.83it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.10it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.33it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.69it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.91it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.06it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.16it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.24it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.30it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.39it/s]
# 100%|██████████| 50/50 [00:03<00:00, 12.96it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 96.551, 'total': 150, 'current': 7, 'sample_id': 's150_007_cat_chair_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.23it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.81it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.47it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.20it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.30it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.97it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.43it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.77it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.97it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.15it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.27it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.35it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.16it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.19it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.01it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.68it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.21it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.59it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.87it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.10it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.17it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.29it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.37it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.43it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.49it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.21it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 100.641, 'total': 150, 'current': 8, 'sample_id': 's150_008_cat_chair_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:17,  2.79it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.11it/s]
#  10%|█         | 5/50 [00:00<00:04,  9.85it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 11.70it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 12.92it/s]
#  22%|██▏       | 11/50 [00:01<00:02, 13.73it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.35it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.72it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.91it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.10it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.21it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.26it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.21it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.23it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.07it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.71it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.25it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.55it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.75it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.96it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.11it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.24it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.32it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.36it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.37it/s]
# 100%|██████████| 50/50 [00:03<00:00, 12.98it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 104.8, 'total': 150, 'current': 9, 'sample_id': 's150_009_cat_chair_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.43it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.10it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.75it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.25it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.23it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.94it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.52it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.85it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.03it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.12it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.30it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.15it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.22it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.06it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.74it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.25it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.62it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.86it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.07it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.24it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.37it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.46it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.50it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.27it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 108.866, 'total': 150, 'current': 10, 'sample_id': 's150_010_dog_bicycle_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.27it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.90it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.57it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.22it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.28it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.96it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.47it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.83it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.01it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.21it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.23it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.32it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.37it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.37it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.13it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.68it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.13it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.43it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.67it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.87it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.09it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.20it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.21it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.31it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.37it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.08it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 112.997, 'total': 150, 'current': 11, 'sample_id': 's150_011_dog_bicycle_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.20it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.77it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.44it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.11it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.24it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.92it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.41it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.76it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.03it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.30it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.41it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.30it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.33it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.16it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.82it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.26it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.62it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.89it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.21it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.35it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.36it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.44it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.20it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 117.092, 'total': 150, 'current': 12, 'sample_id': 's150_012_dog_bicycle_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:16,  3.05it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.52it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.25it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 11.97it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.12it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.88it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.37it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.70it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.91it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.01it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.13it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.29it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.44it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.43it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.26it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.83it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.29it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.62it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.92it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.13it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.29it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.41it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.49it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.52it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.53it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.23it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 121.186, 'total': 150, 'current': 13, 'sample_id': 's150_013_cup_book_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.48it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.20it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.85it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.41it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.48it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.13it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.66it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.96it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.16it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.32it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.45it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.50it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.29it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.36it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.26it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.91it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.43it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.75it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.00it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.16it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.23it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.33it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.31it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.42it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.41it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 125.218, 'total': 150, 'current': 14, 'sample_id': 's150_014_cup_book_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.49it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.22it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.90it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.51it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.50it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.19it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.58it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.78it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.98it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.15it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.10it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.16it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.99it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.66it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.17it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.61it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.88it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.06it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.20it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.30it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.30it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.37it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.41it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.25it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 129.258, 'total': 150, 'current': 15, 'sample_id': 's150_015_cup_book_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.36it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.03it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.70it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.34it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.42it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.15it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.62it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.96it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.18it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.32it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.39it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.44it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.22it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.25it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.11it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.82it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.36it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.75it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.00it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.17it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.31it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.38it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.49it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.54it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.39it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 133.308, 'total': 150, 'current': 16, 'sample_id': 's150_016_vase_flower_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.36it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.02it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.73it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.37it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.40it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.11it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.58it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.80it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.03it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.33it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.40it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.82it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.77it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.47it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.04it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.50it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.88it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.11it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.30it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.42it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.48it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.56it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.53it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.51it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.39it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 137.355, 'total': 150, 'current': 17, 'sample_id': 's150_017_vase_flower_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.58it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.35it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.95it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.48it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.48it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.14it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.61it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.96it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.17it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.30it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.43it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.52it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.64it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.62it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.38it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.97it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.43it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.74it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.19it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.27it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.30it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.42it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.54it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.58it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.36it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 141.399, 'total': 150, 'current': 18, 'sample_id': 's150_018_vase_flower_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:17,  2.76it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.03it/s]
#  10%|█         | 5/50 [00:00<00:04,  9.77it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 11.55it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 12.38it/s]
#  22%|██▏       | 11/50 [00:01<00:02, 13.27it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 13.89it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.29it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.64it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 14.84it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.01it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.15it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.29it/s]
#  54%|█████▍    | 27/50 [00:02<00:02, 11.44it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.41it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.21it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 13.78it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.21it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.58it/s]
#  78%|███████▊  | 39/50 [00:03<00:00, 14.80it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 14.97it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.13it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.29it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.35it/s]
# 100%|██████████| 50/50 [00:03<00:00, 12.67it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 145.68, 'total': 150, 'current': 19, 'sample_id': 's150_019_person_umbrella_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.41it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.13it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.75it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.31it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.22it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.94it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.43it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.75it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.99it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.27it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.32it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.86it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 11.94it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.82it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.49it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.04it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.44it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.70it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.87it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.08it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.36it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.41it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.50it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.24it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 149.776, 'total': 150, 'current': 20, 'sample_id': 's150_020_person_umbrella_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.36it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.03it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.73it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.42it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.46it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.14it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.51it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.82it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.97it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.24it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.28it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.31it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.33it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.16it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.80it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.31it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.68it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.93it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.27it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.38it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.48it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.56it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.59it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.35it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 153.817, 'total': 150, 'current': 21, 'sample_id': 's150_021_person_umbrella_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.64it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.43it/s]
#  10%|█         | 5/50 [00:00<00:04, 11.06it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.64it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.60it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.21it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.64it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.92it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.31it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.37it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.36it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.50it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.48it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.30it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.88it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.30it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.59it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.82it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.01it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.17it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.27it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.32it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.35it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.38it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.43it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 157.842, 'total': 150, 'current': 22, 'sample_id': 's150_022_robot_bench_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.41it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.06it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.70it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.26it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.27it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.99it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.44it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.75it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.97it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.15it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.25it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.35it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.30it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.10it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.74it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.25it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.56it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.84it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.00it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.16it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.24it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.26it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.33it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.32it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.21it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 161.93, 'total': 150, 'current': 23, 'sample_id': 's150_023_robot_bench_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.45it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.10it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.66it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.27it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.33it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.03it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.48it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.85it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.07it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.29it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.37it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.10it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.15it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.00it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.63it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.13it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.49it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.82it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.03it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.17it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.33it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.39it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.39it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.24it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 165.99, 'total': 150, 'current': 24, 'sample_id': 's150_024_robot_bench_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.23it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.79it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.46it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.15it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.25it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.00it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.38it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.63it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.88it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.01it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.31it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.96it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.06it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.96it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.62it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.11it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.58it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.88it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.12it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.26it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.38it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.49it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.49it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.18it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 170.063, 'total': 150, 'current': 25, 'sample_id': 's150_025_bicycle_tree_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.42it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.10it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.75it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.36it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.39it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.04it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.45it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.74it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.93it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.05it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.09it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.16it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.70it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 11.79it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.72it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.45it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.01it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.36it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.68it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.92it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.13it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.25it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.31it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.33it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.39it/s]
# 100%|██████████| 50/50 [00:03<00:00, 12.98it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 174.191, 'total': 150, 'current': 26, 'sample_id': 's150_026_bicycle_tree_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.28it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.85it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.53it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.21it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.29it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.99it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.45it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.77it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.00it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.32it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.43it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.19it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.20it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.03it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.66it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.18it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.36it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.70it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.89it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.06it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.12it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.26it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.29it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.10it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 178.296, 'total': 150, 'current': 27, 'sample_id': 's150_027_bicycle_tree_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.26it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.79it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.47it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.16it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.27it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.98it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.41it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.76it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.04it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.20it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.28it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.37it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.47it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.45it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.24it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.88it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.36it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.71it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.93it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.28it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.33it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.37it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.47it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.51it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.31it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 182.331, 'total': 150, 'current': 28, 'sample_id': 's150_028_dog_bench_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.58it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.31it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.91it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.48it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.50it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.16it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.59it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.83it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.04it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.15it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.30it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.36it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.66it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.54it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.31it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.90it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.37it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.69it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.90it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.15it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.27it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.35it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.42it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.47it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.37it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 186.371, 'total': 150, 'current': 29, 'sample_id': 's150_029_dog_bench_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.15it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.68it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.37it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.10it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.22it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.96it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.41it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.76it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.99it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.29it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.36it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.63it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.58it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.33it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.91it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.34it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.69it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.94it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.16it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.33it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.39it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.48it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.48it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.30it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 190.411, 'total': 150, 'current': 30, 'sample_id': 's150_030_dog_bench_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.32it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.99it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.68it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.27it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.34it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.09it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.53it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.80it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.03it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.23it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.50it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.36it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.34it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.15it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.77it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.29it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.64it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.97it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.16it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.27it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.37it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.55it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.63it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.32it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 194.458, 'total': 150, 'current': 31, 'sample_id': 's150_031_cat_book_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.12it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.65it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.37it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.07it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.20it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.94it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.42it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.75it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.95it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.12it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.34it/s]
#  50%|█████     | 25/50 [00:02<00:02, 10.70it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 11.80it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 12.71it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.36it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 13.93it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.37it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.70it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.91it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.12it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.21it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.27it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.36it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.40it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.09it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 640.307, 'total': 150, 'current': 140, 'sample_id': 's150_140_camera_tripod_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.36it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.98it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.67it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.33it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.35it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.04it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.52it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.71it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.93it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.14it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.23it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.28it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.17it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.18it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.02it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.73it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.25it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.65it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.95it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.30it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.37it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.36it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.44it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.46it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.28it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 644.351, 'total': 150, 'current': 141, 'sample_id': 's150_141_camera_tripod_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.34it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.98it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.63it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.30it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.34it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.05it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.50it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.75it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.94it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.09it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.24it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.35it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.44it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.40it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.21it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.87it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.36it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.74it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.25it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.25it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.31it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.38it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.44it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.25it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 648.466, 'total': 150, 'current': 142, 'sample_id': 's150_142_candle_shelf_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.50it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.20it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.86it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.41it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.43it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.09it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.55it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.89it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.05it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.30it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.48it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.40it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.20it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.78it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.25it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.53it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.71it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.81it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 14.88it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 14.98it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.04it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.15it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.21it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.14it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 652.616, 'total': 150, 'current': 143, 'sample_id': 's150_143_candle_shelf_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.24it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.76it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.41it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.08it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.08it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.77it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.23it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.60it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.85it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 14.98it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.11it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.09it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.12it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.01it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.68it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.19it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.55it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.83it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.98it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.13it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.27it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.33it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.43it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.43it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.03it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 656.77, 'total': 150, 'current': 144, 'sample_id': 's150_144_candle_shelf_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:15,  3.11it/s]
#   6%|▌         | 3/50 [00:00<00:06,  7.59it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.28it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 11.98it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.07it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.82it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.33it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.71it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.94it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.08it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.14it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.17it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.19it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.24it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.03it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.63it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.17it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.49it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.77it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.98it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.14it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.22it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.31it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.35it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.38it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.09it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 660.894, 'total': 150, 'current': 145, 'sample_id': 's150_145_fish_bowl_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.43it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.12it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.73it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.26it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.28it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 13.99it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.51it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.80it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.04it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.28it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.36it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.66it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.60it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.38it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.96it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.44it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.74it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.98it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.21it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.33it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.38it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.47it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.52it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.40it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 664.901, 'total': 150, 'current': 146, 'sample_id': 's150_146_fish_bowl_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.59it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.33it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.96it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.50it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.52it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.21it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.69it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.95it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.26it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.27it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.25it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.27it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.10it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.73it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.23it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.58it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.85it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.05it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.25it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.37it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.40it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.42it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.47it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.34it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 668.919, 'total': 150, 'current': 147, 'sample_id': 's150_147_fish_bowl_detailed_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.29it/s]
#   6%|▌         | 3/50 [00:00<00:05,  7.92it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.59it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.24it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.33it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.02it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.51it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.83it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.08it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.27it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.31it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.37it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.49it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.45it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.22it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.81it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.28it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.52it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.81it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.06it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.20it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.26it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.34it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.40it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.42it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.22it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 673.015, 'total': 150, 'current': 148, 'sample_id': 's150_148_plant_window_photo_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:14,  3.38it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.01it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.66it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.28it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.28it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.01it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.48it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.77it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.99it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.24it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.29it/s]
#  50%|█████     | 25/50 [00:02<00:02, 11.30it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.30it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.10it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.74it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.21it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.55it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.83it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.00it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.19it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.38it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.43it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.42it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.22it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 677.123, 'total': 150, 'current': 149, 'sample_id': 's150_149_plant_window_clear_seed_0000'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:13,  3.56it/s]
#   6%|▌         | 3/50 [00:00<00:05,  8.26it/s]
#  10%|█         | 5/50 [00:00<00:04, 10.90it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 12.51it/s]
#  18%|█▊        | 9/50 [00:00<00:03, 13.51it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.18it/s]
#  26%|██▌       | 13/50 [00:01<00:02, 14.63it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.93it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.09it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.21it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.28it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.26it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.44it/s]
#  54%|█████▍    | 27/50 [00:02<00:01, 12.43it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.20it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.83it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.28it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.65it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.92it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:03<00:00, 15.28it/s]
#  86%|████████▌ | 43/50 [00:03<00:00, 15.34it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.43it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.51it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.52it/s]
# 100%|██████████| 50/50 [00:03<00:00, 13.38it/s]
# sample captured {'stage_id': '01_capture_sd15_full', 'time_sec': 681.161, 'total': 150, 'current': 150, 'sample_id': 's150_150_plant_window_detailed_seed_0000'}
# capture finished

# %%
if (CAPTURE_DIR / "report.json").exists():
    report = json.loads((CAPTURE_DIR / "report.json").read_text(encoding="utf-8"))
    print(report)
    assert report.get("status") == "ok", report
    assert report.get("samples") == NUM_PROMPTS * NUM_SEEDS, report

    sample_dirs = sorted((CAPTURE_DIR / "samples").glob("*"))
    attention_files = sorted((CAPTURE_DIR / "captures").glob("*/attention/step_*/*.pt"))
    activation_files = sorted((CAPTURE_DIR / "captures").glob("*/activations/step_*/*.pt"))
    print("sample dirs:", len(sample_dirs))
    print("attention files:", len(attention_files))
    print("activation files:", len(activation_files))
else:
    print("Stage 1 report is not available yet:", CAPTURE_DIR / "report.json")
# Out:
# {'status': 'ok', 'samples': 150, 'capture_steps': [0, 24, 49], 'installed_attention_layers': ['down_blocks.2.attentions.0.transformer_blocks.0.attn2.processor', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.processor', 'up_blocks.1.attentions.0.transformer_blocks.0.attn2.processor', 'up_blocks.1.attentions.1.transformer_blocks.0.attn2.processor', 'up_blocks.1.attentions.2.transformer_blocks.0.attn2.processor', 'mid_block.attentions.0.transformer_blocks.0.attn2.processor'], 'resolved_activation_modules': ['down_blocks.2.attentions.1', 'mid_block.attentions.0', 'up_blocks.1.attentions.0'], 'output_dir': '/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture'}
# sample dirs: 150
# attention files: 2700
# activation files: 1350

# %% [markdown]
# ## Stage 2a — CLIPSeg pseudo-masks

# %%
MASK_FORCE = False
MASK_MAX_SAMPLES = NUM_PROMPTS * NUM_SEEDS
MASK_THRESHOLD = 0.35
MASK_MIN_FRACTION = 0.005
MASK_FALLBACK_QUANTILE = 0.85


def generate_clipseg_masks(
    samples_dir: Path,
    output_dir: Path,
    *,
    max_samples: int | None = None,
    force: bool = False,
    threshold: float = 0.35,
    min_fraction: float = 0.005,
    fallback_quantile: float = 0.85,
) -> dict:
    import numpy as np
    import torch
    from PIL import Image
    from transformers import CLIPSegForImageSegmentation, CLIPSegProcessor

    if not samples_dir.exists():
        raise FileNotFoundError(samples_dir)

    output_dir.mkdir(parents=True, exist_ok=True)
    sample_dirs = sorted([p for p in samples_dir.iterdir() if p.is_dir()])
    if max_samples is not None:
        sample_dirs = sample_dirs[: int(max_samples)]

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model_id = "CIDAS/clipseg-rd64-refined"
    print("Loading CLIPSeg:", model_id, "device:", device)
    processor = CLIPSegProcessor.from_pretrained(model_id)
    model = CLIPSegForImageSegmentation.from_pretrained(model_id).to(device).eval()

    rows = []
    skipped = {"missing_image": 0, "missing_metadata": 0, "no_entities": 0}

    for idx, sample_dir in enumerate(sample_dirs, start=1):
        image_path = sample_dir / "image.png"
        metadata_path = sample_dir / "metadata.json"
        if not image_path.exists():
            skipped["missing_image"] += 1
            continue
        if not metadata_path.exists():
            skipped["missing_metadata"] += 1
            continue

        metadata = json.loads(metadata_path.read_text(encoding="utf-8"))
        prompt_record = metadata.get("prompt_record", {})
        labels = []
        for ent in prompt_record.get("entities", []) or []:
            if isinstance(ent, dict):
                label = str(ent.get("token") or ent.get("label") or ent.get("name") or "").strip().lower()
            else:
                label = str(ent).strip().lower()
            if label and label not in labels:
                labels.append(label)
        if not labels:
            skipped["no_entities"] += 1
            continue

        image = Image.open(image_path).convert("RGB")
        sample_out = output_dir / sample_dir.name
        sample_out.mkdir(parents=True, exist_ok=True)

        missing_labels = [label for label in labels if force or not (sample_out / f"{label.replace(' ', '_')}.png").exists()]
        if missing_labels:
            with torch.no_grad():
                inputs = processor(
                    text=missing_labels,
                    images=[image] * len(missing_labels),
                    return_tensors="pt",
                    padding=True,
                )
                inputs = {k: (v.to(device) if hasattr(v, "to") else v) for k, v in inputs.items()}
                logits = model(**inputs).logits
                if logits.ndim == 2:
                    logits = logits.unsqueeze(0)
                probs = torch.sigmoid(logits).unsqueeze(1)
                probs = torch.nn.functional.interpolate(
                    probs,
                    size=(image.height, image.width),
                    mode="bilinear",
                    align_corners=False,
                ).squeeze(1).detach().cpu().numpy()

            for label, prob in zip(missing_labels, probs):
                mask = prob >= threshold
                if float(mask.mean()) < min_fraction:
                    adaptive_t = float(np.quantile(prob, fallback_quantile))
                    mask = prob >= adaptive_t
                mask_path = sample_out / f"{label.replace(' ', '_')}.png"
                Image.fromarray((mask.astype(np.uint8) * 255)).save(mask_path)

        for label in labels:
            mask_path = sample_out / f"{label.replace(' ', '_')}.png"
            if mask_path.exists():
                arr = np.array(Image.open(mask_path).convert("L")) > 127
                rows.append({
                    "sample_id": sample_dir.name,
                    "prompt": metadata.get("prompt", ""),
                    "seed": metadata.get("seed"),
                    "label": label,
                    "mask_path": str(mask_path),
                    "mask_area_fraction": float(arr.mean()),
                })

        if idx % 10 == 0 or idx == len(sample_dirs):
            print(f"processed {idx}/{len(sample_dirs)} samples; masks={len(rows)}")

    manifest_columns = ["sample_id", "prompt", "seed", "label", "mask_path", "mask_area_fraction"]
    manifest_df = pd.DataFrame(rows, columns=manifest_columns)
    manifest_df.to_csv(output_dir / "mask_manifest.csv", index=False)
    (output_dir / "mask_manifest.json").write_text(json.dumps(rows, ensure_ascii=False, indent=2), encoding="utf-8")

    report = {
        "status": "ok" if rows else "skipped",
        "samples_seen": len(sample_dirs),
        "samples_with_masks": int(manifest_df["sample_id"].nunique()) if len(manifest_df) else 0,
        "masks": len(rows),
        "output_dir": str(output_dir),
        "threshold": threshold,
        "skipped": skipped,
    }
    (output_dir / "report.json").write_text(json.dumps(report, ensure_ascii=False, indent=2), encoding="utf-8")
    return report


if RUN_DRY_RUNS:
    print({
        "stage": "mask_generation_clipseg",
        "samples_dir": str(CAPTURE_DIR / "samples"),
        "output_dir": str(MASK_DIR),
        "max_samples": MASK_MAX_SAMPLES,
        "force": MASK_FORCE,
    })

if RUN_ACTUAL_STAGES:
    mask_report = generate_clipseg_masks(
        CAPTURE_DIR / "samples",
        MASK_DIR,
        max_samples=MASK_MAX_SAMPLES,
        force=MASK_FORCE,
        threshold=MASK_THRESHOLD,
        min_fraction=MASK_MIN_FRACTION,
        fallback_quantile=MASK_FALLBACK_QUANTILE,
    )
    print(mask_report)
# Out:
# {'stage': 'mask_generation_clipseg', 'samples_dir': '/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/samples', 'output_dir': '/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150', 'max_samples': 150, 'force': False}
# Loading CLIPSeg: CIDAS/clipseg-rd64-refined device: cuda
# 2026-05-10 20:08:54.325564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jupyter/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 10/150 samples; masks=20
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 20/150 samples; masks=40
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 30/150 samples; masks=63
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 40/150 samples; masks=84
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 50/150 samples; masks=109
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 60/150 samples; masks=132
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 70/150 samples; masks=155
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 80/150 samples; masks=175
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 90/150 samples; masks=195
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 100/150 samples; masks=215
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 110/150 samples; masks=235
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 120/150 samples; masks=255
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 130/150 samples; masks=275
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 140/150 samples; masks=295
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# Unused or unrecognized kwargs: padding.
# processed 150/150 samples; masks=315
# {'status': 'ok', 'samples_seen': 150, 'samples_with_masks': 150, 'masks': 315, 'output_dir': '/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150', 'threshold': 0.35, 'skipped': {'missing_image': 0, 'missing_metadata': 0, 'no_entities': 0}}

# %%
mask_manifest_path = MASK_DIR / "mask_manifest.csv"
if mask_manifest_path.exists():
    mask_df = pd.read_csv(mask_manifest_path)
    print("mask rows:", len(mask_df))
    print("samples with masks:", mask_df["sample_id"].nunique())
    display(mask_df.groupby("label").agg(samples=("sample_id", "nunique"), mean_area=("mask_area_fraction", "mean")).sort_values("samples", ascending=False).head(20))
else:
    print("Mask manifest is not available yet:", mask_manifest_path)
# Out:
# mask rows: 315
# samples with masks: 150
#            samples  mean_area
# label
# dog             15   0.102413
# table           15   0.291163
# flower          12   0.349454
# book            12   0.313081
# cup             12   0.138871
# street          12   0.224462
# bicycle         12   0.176302
# person          12   0.099114
# chair            9   0.402229
# grass            9   0.682396
# cat              9   0.368757
# bench            9   0.187143
# tree             9   0.591348
# river            6   0.396520
# car              6   0.127733
# newspaper        6   0.213209
# umbrella         6   0.074107
# vase             6   0.096852
# robot            6   0.114084
# window           6   0.269677

# %% [markdown]
# ## Stage 2b — attention localization

# %%
capture_root = CAPTURE_DIR / "captures"
AVAILABLE_STEPS = sorted({
    int(p.parent.name.split("_")[-1])
    for p in capture_root.glob("*/attention/step_*/*.pt")
})
REQUESTED_STEPS = [0, 24, 49]
USABLE_STEPS = [s for s in REQUESTED_STEPS if s in AVAILABLE_STEPS]

print("AVAILABLE_STEPS:", AVAILABLE_STEPS)
print("USABLE_STEPS:", USABLE_STEPS)
assert USABLE_STEPS, "No requested attention steps were captured."

STAGE2_OVERRIDES = [
    f"data.capture_dir={CAPTURE_DIR / 'captures'}",
    f"data.annotations_dir={MASK_DIR}",
    f"data.output_dir={LOC_DIR}",
    f"metrics.steps={USABLE_STEPS}",
]

if RUN_DRY_RUNS:
    run_config("configs/02_attention_localization/sd15_full.yaml", overrides=STAGE2_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/02_attention_localization/sd15_full.yaml", overrides=STAGE2_OVERRIDES)
    show_report(str(LOC_DIR / "report.json"))
# Out:
# AVAILABLE_STEPS: [0, 24, 49]
# USABLE_STEPS: [0, 24, 49]
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/02_attention_localization/sd15_full.yaml --dry-run --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.annotations_dir=/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150 --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/02_attention_localization --override metrics.steps=[0, 24, 49]
# dry-run attention_localization plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/02_attention_localization/sd15_full.yaml --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.annotations_dir=/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150 --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/02_attention_localization --override metrics.steps=[0, 24, 49]
# attention localization started:   0%|          | 0/2700 [00:00<?, ?it/s]
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 13.726, 'total': 2700, 'current': 32}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 14.695, 'total': 2700, 'current': 64}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 15.69, 'total': 2700, 'current': 96}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 16.704, 'total': 2700, 'current': 128}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 17.79, 'total': 2700, 'current': 160}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 18.728, 'total': 2700, 'current': 192}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 19.647, 'total': 2700, 'current': 224}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 20.687, 'total': 2700, 'current': 256}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 21.952, 'total': 2700, 'current': 288}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 22.936, 'total': 2700, 'current': 320}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 24.031, 'total': 2700, 'current': 352}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 25.021, 'total': 2700, 'current': 384}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 26.186, 'total': 2700, 'current': 416}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 27.329, 'total': 2700, 'current': 448}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 28.361, 'total': 2700, 'current': 480}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 29.426, 'total': 2700, 'current': 512}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 30.463, 'total': 2700, 'current': 544}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 31.503, 'total': 2700, 'current': 576}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 32.526, 'total': 2700, 'current': 608}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 33.572, 'total': 2700, 'current': 640}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 34.659, 'total': 2700, 'current': 672}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 35.693, 'total': 2700, 'current': 704}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 36.869, 'total': 2700, 'current': 736}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 38.101, 'total': 2700, 'current': 768}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 39.342, 'total': 2700, 'current': 800}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 40.489, 'total': 2700, 'current': 832}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 41.626, 'total': 2700, 'current': 864}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 42.749, 'total': 2700, 'current': 896}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 43.887, 'total': 2700, 'current': 928}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 44.94, 'total': 2700, 'current': 960}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 45.951, 'total': 2700, 'current': 992}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 46.981, 'total': 2700, 'current': 1024}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 48.125, 'total': 2700, 'current': 1056}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 49.139, 'total': 2700, 'current': 1088}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 50.165, 'total': 2700, 'current': 1120}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 51.453, 'total': 2700, 'current': 1152}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 52.753, 'total': 2700, 'current': 1184}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 53.83, 'total': 2700, 'current': 1216}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 55.036, 'total': 2700, 'current': 1248}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 56.073, 'total': 2700, 'current': 1280}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 57.329, 'total': 2700, 'current': 1312}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 58.344, 'total': 2700, 'current': 1344}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 59.355, 'total': 2700, 'current': 1376}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 60.352, 'total': 2700, 'current': 1408}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 61.32, 'total': 2700, 'current': 1440}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 62.398, 'total': 2700, 'current': 1472}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 63.447, 'total': 2700, 'current': 1504}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 64.489, 'total': 2700, 'current': 1536}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 65.566, 'total': 2700, 'current': 1568}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 66.834, 'total': 2700, 'current': 1600}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 68.129, 'total': 2700, 'current': 1632}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 69.28, 'total': 2700, 'current': 1664}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 70.378, 'total': 2700, 'current': 1696}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 71.523, 'total': 2700, 'current': 1728}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 72.604, 'total': 2700, 'current': 1760}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 73.737, 'total': 2700, 'current': 1792}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 74.809, 'total': 2700, 'current': 1824}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 75.821, 'total': 2700, 'current': 1856}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 76.884, 'total': 2700, 'current': 1888}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 77.857, 'total': 2700, 'current': 1920}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 78.947, 'total': 2700, 'current': 1952}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 79.94, 'total': 2700, 'current': 1984}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 80.948, 'total': 2700, 'current': 2016}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 82.245, 'total': 2700, 'current': 2048}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 83.587, 'total': 2700, 'current': 2080}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 84.768, 'total': 2700, 'current': 2112}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 85.962, 'total': 2700, 'current': 2144}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 86.976, 'total': 2700, 'current': 2176}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 88.131, 'total': 2700, 'current': 2208}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 89.327, 'total': 2700, 'current': 2240}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 90.501, 'total': 2700, 'current': 2272}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 91.573, 'total': 2700, 'current': 2304}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 92.677, 'total': 2700, 'current': 2336}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 93.762, 'total': 2700, 'current': 2368}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 94.762, 'total': 2700, 'current': 2400}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 95.732, 'total': 2700, 'current': 2432}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 96.966, 'total': 2700, 'current': 2464}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 98.234, 'total': 2700, 'current': 2496}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 99.528, 'total': 2700, 'current': 2528}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 100.759, 'total': 2700, 'current': 2560}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 101.864, 'total': 2700, 'current': 2592}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 103.028, 'total': 2700, 'current': 2624}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 104.091, 'total': 2700, 'current': 2656}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 105.108, 'total': 2700, 'current': 2688}
# attention files processed {'stage_id': '02_attention_localization_sd15_full', 'time_sec': 105.484, 'total': 2700, 'current': 2700}
# attention localization finished

# %%
loc_rows_path = LOC_DIR / "attention_localization_rows.csv"
if loc_rows_path.exists():
    loc_df = pd.read_csv(loc_rows_path)
    print("localization rows:", len(loc_df))
    if len(loc_df):
        display(
            loc_df.groupby("step")
            .agg(
                n=("iou", "count"),
                iou_mean=("iou", "mean"),
                iou_median=("iou", "median"),
                centroid_mean=("centroid_distance", "mean"),
                entropy_mean=("entropy", "mean"),
            )
            .reset_index()
        )
else:
    print("Localization rows are not available yet:", loc_rows_path)
# Out:
# localization rows: 5670
#    step     n  iou_mean  iou_median  centroid_mean  entropy_mean
# 0     0  1890  0.327716    0.309934       2.651216      0.938926
# 1    24  1890  0.338309    0.300000       2.199509      0.886840
# 2    49  1890  0.286803    0.247771       2.252398      0.888890

# %% [markdown]
# ## Stage 3 — SAE training

# %%
SAE_OVERRIDES = [
    f"data.capture_dir={CAPTURE_DIR / 'captures'}",
    f"data.output_dir={SAE_DIR}",
    "sae.layer=mid_block.attentions.0",
    "sae.step=24",
    "sae.num_epochs=5",
    f"sae.max_activation_files={NUM_PROMPTS * NUM_SEEDS}",
    "sae.max_tokens_per_file=4096",
    "sae.k=20",
    "sae.expansion_factor=4",
]

if RUN_DRY_RUNS:
    run_config("configs/03_sae_training/sd15_full.yaml", overrides=SAE_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/03_sae_training/sd15_full.yaml", overrides=SAE_OVERRIDES)
    show_report(str(SAE_DIR / "report.json"))
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/03_sae_training/sd15_full.yaml --dry-run --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid --override sae.layer=mid_block.attentions.0 --override sae.step=24 --override sae.num_epochs=5 --override sae.max_activation_files=150 --override sae.max_tokens_per_file=4096 --override sae.k=20 --override sae.expansion_factor=4
# dry-run sae_training plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/03_sae_training/sd15_full.yaml --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid --override sae.layer=mid_block.attentions.0 --override sae.step=24 --override sae.num_epochs=5 --override sae.max_activation_files=150 --override sae.max_tokens_per_file=4096 --override sae.k=20 --override sae.expansion_factor=4
# SAE training started:   0%|          | 0/5 [00:00<?, ?it/s]
# SAE epoch completed {'stage_id': '03_sae_training_sd15_full', 'time_sec': 17.369, 'total': 5, 'current': 1, 'epoch': 0, 'mean_loss': 6.1087054475148514, 'mean_reconstruction_loss': 6.1087054475148514, 'active_fraction': 0.00390625, 'batches': 150}
# SAE epoch completed {'stage_id': '03_sae_training_sd15_full', 'time_sec': 19.277, 'total': 5, 'current': 2, 'epoch': 1, 'mean_loss': 5.174759132067362, 'mean_reconstruction_loss': 5.174759132067362, 'active_fraction': 0.00390625, 'batches': 150}
# SAE epoch completed {'stage_id': '03_sae_training_sd15_full', 'time_sec': 21.645, 'total': 5, 'current': 3, 'epoch': 2, 'mean_loss': 4.3077776273091635, 'mean_reconstruction_loss': 4.3077776273091635, 'active_fraction': 0.00390625, 'batches': 150}
# SAE epoch completed {'stage_id': '03_sae_training_sd15_full', 'time_sec': 23.913, 'total': 5, 'current': 4, 'epoch': 3, 'mean_loss': 3.6561556911468505, 'mean_reconstruction_loss': 3.6561556911468505, 'active_fraction': 0.00390625, 'batches': 150}
# SAE epoch completed {'stage_id': '03_sae_training_sd15_full', 'time_sec': 26.305, 'total': 5, 'current': 5, 'epoch': 4, 'mean_loss': 3.1836229507128397, 'mean_reconstruction_loss': 3.1836229507128397, 'active_fraction': 0.00390625, 'batches': 150}
# SAE training finished

# %%
history_path = SAE_DIR / "history.json"
if history_path.exists():
    hist = json.loads(history_path.read_text(encoding="utf-8"))["history"]
    hist_df = pd.DataFrame(hist)
    display(hist_df)
else:
    print("SAE history is not available yet:", history_path)
# Out:
#    epoch  mean_loss  mean_reconstruction_loss  active_fraction  batches
# 0      0   6.108705                  6.108705         0.003906      150
# 1      1   5.174759                  5.174759         0.003906      150
# 2      2   4.307778                  4.307778         0.003906      150
# 3      3   3.656156                  3.656156         0.003906      150
# 4      4   3.183623                  3.183623         0.003906      150

# %% [markdown]
# ## Stage 4 — concept dictionary

# %%
STAGE4_OVERRIDES = [
    f"data.capture_dir={CAPTURE_DIR / 'captures'}",
    f"data.annotations_dir={MASK_DIR}",
    f"data.sae_checkpoint={SAE_DIR / 'sae.pt'}",
    f"data.output_dir={CONCEPT_DIR}",
    "dictionary.layer=mid_block.attentions.0",
    "dictionary.step=24",
    f"dictionary.max_activation_files={NUM_PROMPTS * NUM_SEEDS}",
    "dictionary.top_k_features_per_label=20",
]

if RUN_DRY_RUNS:
    run_config("configs/04_concept_dictionary/sd15_full.yaml", overrides=STAGE4_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/04_concept_dictionary/sd15_full.yaml", overrides=STAGE4_OVERRIDES)
    show_report(str(CONCEPT_DIR / "report.json"))
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/04_concept_dictionary/sd15_full.yaml --dry-run --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.annotations_dir=/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150 --override data.sae_checkpoint=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid/sae.pt --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/04_concept_dictionary --override dictionary.layer=mid_block.attentions.0 --override dictionary.step=24 --override dictionary.max_activation_files=150 --override dictionary.top_k_features_per_label=20
# dry-run concept_dictionary plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/04_concept_dictionary/sd15_full.yaml --override data.capture_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/01_capture/captures --override data.annotations_dir=/home/jupyter/project/diffusion_attention_analysis_2/annotations/sd15_150 --override data.sae_checkpoint=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid/sae.pt --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/04_concept_dictionary --override dictionary.layer=mid_block.attentions.0 --override dictionary.step=24 --override dictionary.max_activation_files=150 --override dictionary.top_k_features_per_label=20
# concept dictionary started:   0%|          | 0/150 [00:00<?, ?it/s]
# concept files processed {'stage_id': '04_concept_dictionary_sd15_full', 'time_sec': 14.196, 'total': 150, 'current': 32}
# concept files processed {'stage_id': '04_concept_dictionary_sd15_full', 'time_sec': 15.227, 'total': 150, 'current': 64}
# concept files processed {'stage_id': '04_concept_dictionary_sd15_full', 'time_sec': 16.242, 'total': 150, 'current': 96}
# concept files processed {'stage_id': '04_concept_dictionary_sd15_full', 'time_sec': 17.182, 'total': 150, 'current': 128}
# concept files processed {'stage_id': '04_concept_dictionary_sd15_full', 'time_sec': 17.827, 'total': 150, 'current': 150}
# concept dictionary finished

# %%
concept_csv = CONCEPT_DIR / "concept_dictionary.csv"
if concept_csv.exists():
    concept_df = pd.read_csv(concept_csv)
    print("concept rows:", len(concept_df))
    print("labels:", concept_df["label"].nunique() if len(concept_df) else 0)
    if len(concept_df):
        label_summary = (
            concept_df.groupby("label")
            .agg(
                mask_count=("count", "first"),
                top_score=("score", "max"),
                mean_top_score=("score", "mean"),
                n_features=("feature_id", "count"),
            )
            .sort_values(["top_score", "mask_count"], ascending=False)
        )
        display(label_summary.head(30))
else:
    print("Concept dictionary is not available yet:", concept_csv)
# Out:
# concept rows: 1220
# labels: 61
#             mask_count  top_score  mean_top_score  n_features
# label
# boat                 3  46.650223       35.300118          20
# bridge               3  37.237904       25.350232          20
# umbrella             6  37.161377       30.396213          20
# newspaper            6  32.462055       15.220629          20
# skateboard           3  31.621964       15.815258          20
# shoes                3  30.452971       24.135484          20
# vase                 6  28.733355       17.217216          20
# hat                  3  28.169754       19.959068          20
# pizza                3  27.655443       22.685304          20
# banana               3  27.292871       17.162829          20
# bird                 3  25.498449       18.109954          20
# tripod               3  25.228823       18.343785          20
# bus                  3  25.001883       16.232471          20
# door                 3  23.666245       13.982164          20
# train                3  23.422083       16.066704          20
# dog                 15  23.131441       15.399764          20
# book                12  23.092260       16.704861          20
# phone                3  22.796507       15.047447          20
# bottle               3  22.563444       14.009846          20
# horse                3  22.412706       16.918168          20
# mountain             3  22.113825       14.447219          20
# airplane             3  21.994614       14.129617          20
# bicycle             12  20.209995       13.290827          20
# plant                3  19.013208        9.684000          20
# basket               3  18.924021       11.166858          20
# bear                 3  18.778749       13.275933          20
# clock                3  18.716791       11.243690          20
# candle               2  18.695427        9.316728          20
# bed                  3  18.526062       10.054523          20
# plate                3  18.351551       10.806644          20

# %% [markdown]
# ## Stage 5 — causal probes

# %%
STAGE5_MAX_PROMPTS = NUM_PROMPTS
MAP_STRENGTHS = [2.0]
SAE_BETAS = [2.0]
LABELS_FOR_STEERING = ["dog", "cat", "car", "person", "tree", "book", "flower", "cup", "vase", "bicycle"]
MAX_CONCEPT_IDS = 8

concept_csv = CONCEPT_DIR / "concept_dictionary.csv"
if concept_csv.exists():
    concept_df = pd.read_csv(concept_csv)
    selected = (
        concept_df[concept_df["label"].isin(LABELS_FOR_STEERING)]
        .sort_values(["label", "score"], ascending=[True, False])
        .groupby("label")
        .head(1)
        .copy()
    )
    if selected.empty and len(concept_df):
        selected = concept_df.sort_values("score", ascending=False).head(MAX_CONCEPT_IDS).copy()
    CONCEPT_IDS_150 = sorted(selected["feature_id"].astype(int).unique().tolist())[:MAX_CONCEPT_IDS]
    print("CONCEPT_IDS_150:", CONCEPT_IDS_150)
    display(selected)
else:
    CONCEPT_IDS_150 = []
    print("Concept dictionary is missing; Stage 5b will not run until Stage 4 is complete.")
# Out:
# CONCEPT_IDS_150: [290, 497, 1436, 1649, 2233, 4235, 4372, 4957]
#        label  count  feature_id      score
# 120  bicycle     12         290  20.209995
# 140     book     12        5088  23.092260
# 40       car      6        1436  11.487144
# 80       cat      9        4957  10.854559
# 160      cup     12        2233   9.212723
# 0        dog     15        1649  23.131441
# 180   flower     12        4372  11.054782
# 220   person     11        4235   8.545428
# 320     tree      9        4372   8.441313
# 200     vase      6         497  28.733355

# %% [markdown]
# ### Stage 5a — map-level intervention

# %%
MAP_OVERRIDES = [
    f"data.prompts_path={INTERVENTION_PROMPTS_150}",
    f"data.output_dir={MAP_DIR}",
    f"data.max_prompts={STAGE5_MAX_PROMPTS}",
    "runtime.seed_start=0",
    f"runtime.num_seeds={NUM_SEEDS}",
    f"intervention.strengths={MAP_STRENGTHS}",
    "intervention.target_steps=[24]",
    "intervention.outside_multiplier=1.0",
]

if RUN_DRY_RUNS:
    run_config("configs/05_interventions/sd15_map_reweight.yaml", overrides=MAP_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/05_interventions/sd15_map_reweight.yaml", overrides=MAP_OVERRIDES)
    show_report(str(MAP_DIR / "report.json"))
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/05_interventions/sd15_map_reweight.yaml --dry-run --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_intervention_prompts.jsonl --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/05_intervention_map_reweight --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override intervention.strengths=[2.0] --override intervention.target_steps=[24] --override intervention.outside_multiplier=1.0
# dry-run intervention plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/05_interventions/sd15_map_reweight.yaml --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_intervention_prompts.jsonl --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/05_intervention_map_reweight --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override intervention.strengths=[2.0] --override intervention.target_steps=[24] --override intervention.outside_multiplier=1.0
# 2026-05-10 20:22:26.760434: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:20: FutureWarning: `VQEncoderOutput` is deprecated and will be removed in version 0.31. Importing `VQEncoderOutput` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQEncoderOutput`, instead.
#   deprecate("VQEncoderOutput", "0.31", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:25: FutureWarning: `VQModel` is deprecated and will be removed in version 0.31. Importing `VQModel` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQModel`, instead.
#   deprecate("VQModel", "0.31", deprecation_message)
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:04<00:11,  2.29s/it]
# Loading pipeline components...:  43%|████▎     | 3/7 [00:04<00:05,  1.39s/it]
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:23<00:23,  7.81s/it]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:25<00:04,  4.41s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:28<00:00,  3.83s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:28<00:00,  4.00s/it]
# map intervention started:   0%|          | 0/150 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:01<01:30,  1.85s/it]
#   6%|▌         | 3/50 [00:01<00:24,  1.89it/s]
#  10%|█         | 5/50 [00:02<00:13,  3.43it/s]
#  14%|█▍        | 7/50 [00:02<00:08,  5.11it/s]
#  18%|█▊        | 9/50 [00:02<00:06,  6.82it/s]
#  22%|██▏       | 11/50 [00:02<00:04,  8.45it/s]
#  26%|██▌       | 13/50 [00:02<00:03,  9.94it/s]
#  30%|███       | 15/50 [00:02<00:03, 11.22it/s]
#  34%|███▍      | 17/50 [00:02<00:02, 12.25it/s]
#  38%|███▊      | 19/50 [00:03<00:02, 13.10it/s]
#  42%|████▏     | 21/50 [00:03<00:02, 13.77it/s]
#  46%|████▌     | 23/50 [00:03<00:01, 14.25it/s]
#  50%|█████     | 25/50 [00:03<00:02, 10.86it/s]
#  54%|█████▍    | 27/50 [00:03<00:01, 11.90it/s]
#  58%|█████▊    | 29/50 [00:03<00:01, 12.77it/s]
#  62%|██████▏   | 31/50 [00:03<00:01, 13.48it/s]
#  66%|██████▌   | 33/50 [00:04<00:01, 14.05it/s]
#  70%|███████   | 35/50 [00:04<00:01, 14.47it/s]
#  74%|███████▍  | 37/50 [00:04<00:00, 14.75it/s]
#  78%|███████▊  | 39/50 [00:04<00:00, 14.99it/s]
#  82%|████████▏ | 41/50 [00:04<00:00, 15.13it/s]
#  86%|████████▌ | 43/50 [00:04<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:04<00:00, 15.25it/s]
#  94%|█████████▍| 47/50 [00:04<00:00, 15.27it/s]
#  98%|█████████▊| 49/50 [00:05<00:00, 15.31it/s]
# 100%|██████████| 50/50 [00:05<00:00,  9.63it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 59.921, 'total': 150, 'current': 1, 'sample_id': 's150_001_dog_grass_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.66it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.17it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.62it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.31it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.63it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.82it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.06it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.16it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.24it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.32it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.27it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.30it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.45it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.98it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.37it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.65it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.82it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.98it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.09it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.16it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.21it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.24it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.30it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.36it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.77it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 63.585, 'total': 150, 'current': 2, 'sample_id': 's150_002_dog_grass_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.61it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.14it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.60it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.23it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.61it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.77it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.86it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.93it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.02it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.09it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.09it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.14it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.18it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.72it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.15it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.44it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.69it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.88it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.05it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.11it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.08it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.13it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.15it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.15it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.20it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.63it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 67.287, 'total': 150, 'current': 3, 'sample_id': 's150_003_dog_grass_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.60it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.02it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.51it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.12it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.61it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.86it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.99it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.12it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.24it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.24it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.05it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.61it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.02it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.32it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.55it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.66it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.85it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.93it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 14.92it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.03it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.08it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.07it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.00it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.57it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 71.03, 'total': 150, 'current': 4, 'sample_id': 's150_004_car_street_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.56it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.11it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.40it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.12it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.53it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.77it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.96it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.06it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.09it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.18it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.24it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.25it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.16it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.73it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.18it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.50it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.71it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.90it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.03it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.15it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.21it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.25it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.33it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.32it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.33it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.69it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 74.746, 'total': 150, 'current': 5, 'sample_id': 's150_005_car_street_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.12it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.57it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.25it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.66it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.87it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.01it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.04it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.13it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.13it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.11it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.14it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.16it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.74it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.13it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.48it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.70it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.86it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.15it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.24it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.18it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.20it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.25it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.27it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.68it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 78.462, 'total': 150, 'current': 6, 'sample_id': 's150_006_car_street_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.20it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.66it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.33it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.67it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.80it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.93it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.05it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.07it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.09it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.15it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.16it/s]
#  50%|█████     | 25/50 [00:01<00:01, 12.90it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.51it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.00it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.33it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.56it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.69it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.89it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.96it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.05it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.05it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.07it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.09it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.14it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.58it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 82.204, 'total': 150, 'current': 7, 'sample_id': 's150_007_cat_chair_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.56it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.03it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.43it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.08it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.51it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.77it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.84it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.99it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.05it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.09it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.12it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.16it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.17it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.73it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.16it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.44it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.71it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.87it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.98it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.02it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.08it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.10it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.10it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.15it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.16it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.61it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 85.947, 'total': 150, 'current': 8, 'sample_id': 's150_008_cat_chair_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.14it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.49it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.12it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.51it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.71it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.87it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.03it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.27it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.38it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.89it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.30it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.60it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.82it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.94it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.08it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.15it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.18it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.24it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.25it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.15it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.18it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.70it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 89.676, 'total': 150, 'current': 9, 'sample_id': 's150_009_cat_chair_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.56it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.07it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.50it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.17it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.56it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.81it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.98it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.04it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.08it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.17it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.78it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.19it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.73it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.89it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.06it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.14it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.18it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.15it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.21it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.26it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.67it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 93.401, 'total': 150, 'current': 10, 'sample_id': 's150_010_dog_bicycle_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.73it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.18it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.66it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.35it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.71it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.96it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.03it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.02it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.08it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.13it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.16it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.20it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.76it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.19it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.50it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.69it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.87it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.02it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.14it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.18it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.23it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.19it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.68it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 97.111, 'total': 150, 'current': 11, 'sample_id': 's150_011_dog_bicycle_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.61it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.15it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.60it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.32it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.68it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.92it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.14it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.22it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.28it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.32it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.38it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.40it/s]
#  50%|█████     | 25/50 [00:01<00:02, 11.66it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 12.57it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.30it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 13.92it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.33it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.64it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.83it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.00it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.13it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.16it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.28it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.26it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.48it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 100.89, 'total': 150, 'current': 12, 'sample_id': 's150_012_dog_bicycle_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.63it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.07it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.58it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.30it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.64it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.89it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.10it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.24it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.38it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.40it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.26it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.84it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.29it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.63it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.87it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.03it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.15it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.25it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.32it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.35it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.42it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.45it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.50it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.83it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 104.582, 'total': 150, 'current': 13, 'sample_id': 's150_013_cup_book_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.30it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.78it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.40it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.77it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.97it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.17it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.26it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.35it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.36it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.40it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.43it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.40it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.88it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.27it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.57it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.82it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.99it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.11it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.18it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.24it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.31it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.34it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.39it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.38it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.82it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 108.272, 'total': 150, 'current': 14, 'sample_id': 's150_014_cup_book_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.67it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.21it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.66it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.31it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.69it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.95it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.02it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.05it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.08it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.14it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.15it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.19it/s]
#  50%|█████     | 25/50 [00:01<00:02, 12.42it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.15it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.73it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.13it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.43it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.61it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.81it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.91it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.01it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.07it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.10it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.05it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.07it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.50it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 112.026, 'total': 150, 'current': 15, 'sample_id': 's150_015_cup_book_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.55it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.00it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.49it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.17it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.50it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.80it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.01it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.11it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.15it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.18it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.19it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.02it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.62it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.03it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.38it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.60it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.79it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.90it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.99it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.04it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.10it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.12it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.19it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.20it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.61it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 115.795, 'total': 150, 'current': 16, 'sample_id': 's150_016_vase_flower_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.60it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.07it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.48it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.20it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.58it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.73it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.86it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.97it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.08it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.21it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.20it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.13it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.69it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.17it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.79it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.97it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.11it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.24it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.30it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.35it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.36it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.38it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.34it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.70it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 119.529, 'total': 150, 'current': 17, 'sample_id': 's150_017_vase_flower_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.57it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.08it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.59it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.34it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.74it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.96it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.12it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.19it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.26it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.29it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.34it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.38it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.21it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.76it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.18it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.43it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.67it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.85it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.94it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.04it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.13it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.17it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.19it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.23it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.70it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 123.222, 'total': 150, 'current': 18, 'sample_id': 's150_018_vase_flower_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.20it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.63it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.28it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.69it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.97it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.08it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.16it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.19it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.18it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.21it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.18it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.16it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.73it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.20it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.74it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.93it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.03it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.11it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.17it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.21it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.20it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.23it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.69it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 126.961, 'total': 150, 'current': 19, 'sample_id': 's150_019_person_umbrella_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.61it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.14it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.64it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.32it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.76it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.99it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.11it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.19it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.25it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.30it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.35it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.44it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.56it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 14.06it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.43it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.66it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.83it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.94it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.07it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.10it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.12it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.16it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.17it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.22it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.23it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.77it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 130.67, 'total': 150, 'current': 20, 'sample_id': 's150_020_person_umbrella_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.17it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.67it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.23it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.69it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.94it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.13it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.16it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.26it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.34it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.38it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.34it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.41it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.91it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.33it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.64it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.84it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.92it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.01it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.13it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.14it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.26it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.35it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.37it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.78it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 134.364, 'total': 150, 'current': 21, 'sample_id': 's150_021_person_umbrella_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.66it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.19it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.71it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.35it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.69it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.89it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.04it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.14it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.22it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.27it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.31it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.25it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.82it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.25it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.56it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.77it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.94it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.03it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.13it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.15it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.25it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.28it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.29it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.74it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 138.075, 'total': 150, 'current': 22, 'sample_id': 's150_022_robot_bench_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.16it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.66it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.29it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.67it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.84it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.96it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.01it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.97it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 14.98it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.01it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.03it/s]
#  50%|█████     | 25/50 [00:01<00:01, 12.56it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.24it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.76it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.21it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.49it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.69it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.83it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.93it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 14.97it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.06it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.05it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.05it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.08it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.50it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 141.85, 'total': 150, 'current': 23, 'sample_id': 's150_023_robot_bench_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.60it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.12it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.54it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.20it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.57it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.80it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.95it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.05it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.13it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.18it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.00it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.62it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.05it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.37it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.63it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.81it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.95it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.07it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.12it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.12it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.12it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.18it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.21it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.62it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 145.592, 'total': 150, 'current': 24, 'sample_id': 's150_024_robot_bench_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.54it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.01it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.47it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.15it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.52it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.74it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.88it/s]
#  30%|███       | 15/50 [00:01<00:02, 14.95it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 14.93it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.02it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.09it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.19it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.19it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.76it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.17it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.45it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.69it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.85it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.96it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.11it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.20it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.23it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.31it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.33it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.30it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.65it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 149.303, 'total': 150, 'current': 25, 'sample_id': 's150_025_bicycle_tree_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.62it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.11it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.53it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.27it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.65it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.92it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.07it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.17it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.26it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.29it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.30it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.34it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.30it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.87it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.29it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.59it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.78it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.89it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.11it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.15it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.19it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.26it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.34it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.39it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.75it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 152.98, 'total': 150, 'current': 26, 'sample_id': 's150_026_bicycle_tree_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.57it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.11it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.62it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.35it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.71it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.87it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.97it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.10it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.16it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.18it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.19it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.06it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.67it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.14it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.46it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.69it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.87it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.01it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.14it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.21it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.27it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.26it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.29it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.23it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.68it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 156.673, 'total': 150, 'current': 27, 'sample_id': 's150_027_bicycle_tree_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.55it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.05it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.57it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.27it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.67it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.93it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.07it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.11it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.18it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.23it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.27it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.32it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.16it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.77it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.21it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.58it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.83it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.98it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.06it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.17it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.23it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.27it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.29it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.35it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.33it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.73it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 160.37, 'total': 150, 'current': 28, 'sample_id': 's150_028_dog_bench_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.51it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.06it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.51it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.23it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.63it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.82it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.99it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.12it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.20it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.20it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.17it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.21it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.02it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.59it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.08it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.39it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.62it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.73it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.91it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.02it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.04it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.07it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.12it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.17it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.20it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.62it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 164.101, 'total': 150, 'current': 29, 'sample_id': 's150_029_dog_bench_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.66it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.20it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.63it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.22it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.62it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.85it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.98it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.08it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.12it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.19it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.20it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:01<00:01, 12.98it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.57it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.07it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.39it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.65it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.82it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.96it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.96it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.01it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.09it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.06it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.13it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.15it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.61it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 167.816, 'total': 150, 'current': 30, 'sample_id': 's150_030_dog_bench_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.59it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.05it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.53it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.28it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.65it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.89it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.95it/s]
# ...
#  14%|█▍        | 7/50 [00:00<00:03, 14.12it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.54it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.77it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.91it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.01it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.10it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.15it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.09it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.19it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.15it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.75it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.16it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.74it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.91it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.05it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.12it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.14it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.21it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.24it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.27it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.66it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 578.059, 'total': 150, 'current': 140, 'sample_id': 's150_140_camera_tripod_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.23it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.71it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.33it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.63it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.86it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.06it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.13it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.11it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.22it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.29it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.25it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.86it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.32it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.58it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.76it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.88it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.99it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.08it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.07it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.18it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.20it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.18it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.70it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 581.761, 'total': 150, 'current': 141, 'sample_id': 's150_141_camera_tripod_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.52it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.06it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.56it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.24it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.63it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.87it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.05it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.11it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.22it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.28it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.30it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.28it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.41it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.85it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.25it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.80it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.00it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.15it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.21it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.26it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.30it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.30it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.32it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.30it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.75it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 585.507, 'total': 150, 'current': 142, 'sample_id': 's150_142_candle_shelf_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.19it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.70it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.41it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.79it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.93it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.06it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.13it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.21it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.21it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.21it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.29it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.26it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.83it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.30it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.63it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.81it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.97it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.09it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.20it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.30it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.32it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.30it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.21it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.25it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.76it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 589.272, 'total': 150, 'current': 143, 'sample_id': 's150_143_candle_shelf_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.56it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.08it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.47it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.19it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.63it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.80it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.94it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.05it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.10it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.16it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.23it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.26it/s]
#  50%|█████     | 25/50 [00:01<00:01, 12.52it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.22it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.76it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.12it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.49it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.73it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.90it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.99it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.09it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.09it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.13it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.17it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.24it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.54it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 593.041, 'total': 150, 'current': 144, 'sample_id': 's150_144_candle_shelf_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.68it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.15it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.54it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.20it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.50it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.67it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.86it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.00it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.13it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.17it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.25it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.25it/s]
#  50%|█████     | 25/50 [00:01<00:01, 12.71it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.40it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 13.91it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.29it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.55it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.71it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.89it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 14.95it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 14.99it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.07it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.15it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.18it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.24it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.57it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 596.795, 'total': 150, 'current': 145, 'sample_id': 's150_145_fish_bowl_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.24it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.65it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.32it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.73it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.95it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.07it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.14it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.23it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.28it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.27it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.27it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.78it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.18it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.53it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.76it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.85it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.98it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.06it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.11it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.14it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.22it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.26it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.31it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.72it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 600.491, 'total': 150, 'current': 146, 'sample_id': 's150_146_fish_bowl_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.59it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.09it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.57it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.27it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.65it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.91it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.06it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.19it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.23it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.24it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.29it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.36it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.57it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 14.07it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.78it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.93it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.07it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.19it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.27it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.24it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.27it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.30it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.29it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.24it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.80it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 604.158, 'total': 150, 'current': 147, 'sample_id': 's150_147_fish_bowl_detailed_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.51it/s]
#   6%|▌         | 3/50 [00:00<00:03, 11.94it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.40it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.15it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.48it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.77it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.94it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.06it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.16it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.18it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.23it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.28it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.17it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.76it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.20it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.75it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.87it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.96it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.09it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.14it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.21it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.26it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.30it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.35it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.68it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 607.913, 'total': 150, 'current': 148, 'sample_id': 's150_148_plant_window_photo_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.21it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.64it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.29it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.73it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.97it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.06it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.18it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.22it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.20it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.24it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.28it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.15it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.69it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.13it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.48it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.70it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.84it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.98it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.02it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.08it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.09it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.18it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.21it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.24it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.68it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 611.67, 'total': 150, 'current': 149, 'sample_id': 's150_149_plant_window_clear_seed_0000_x2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.55it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.05it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.55it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.18it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.57it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.79it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.95it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.03it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.09it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.13it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.10it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.13it/s]
#  50%|█████     | 25/50 [00:01<00:01, 13.11it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 13.68it/s]
#  58%|█████▊    | 29/50 [00:02<00:01, 14.05it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 14.33it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 14.64it/s]
#  70%|███████   | 35/50 [00:02<00:01, 14.79it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 14.94it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.03it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.09it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.10it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.14it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.18it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.20it/s]
# 100%|██████████| 50/50 [00:03<00:00, 14.61it/s]
# map intervention generated {'stage_id': '05_intervention_sd15_map_reweight', 'time_sec': 615.414, 'total': 150, 'current': 150, 'sample_id': 's150_150_plant_window_detailed_seed_0000_x2'}
# map intervention finished

# %% [markdown]
# ### Stage 5b — SAE feature steering

# %%
assert CONCEPT_IDS_150, "No concept IDs selected. Run Stage 4 first or adjust LABELS_FOR_STEERING."

SAE_STEER_OVERRIDES = [
    f"data.prompts_path={INTERVENTION_PROMPTS_150}",
    f"data.sae_checkpoint={SAE_DIR / 'sae.pt'}",
    f"data.output_dir={SAE_STEER_DIR}",
    f"data.max_prompts={STAGE5_MAX_PROMPTS}",
    "runtime.seed_start=0",
    f"runtime.num_seeds={NUM_SEEDS}",
    "intervention.module=mid_block.attentions.0",
    "intervention.target_steps=[24]",
    f"intervention.concept_ids={CONCEPT_IDS_150}",
    f"intervention.betas={SAE_BETAS}",
]

if RUN_DRY_RUNS:
    run_config("configs/05_interventions/sd15_sae_steering.yaml", overrides=SAE_STEER_OVERRIDES, dry_run=True)

if RUN_ACTUAL_STAGES:
    run_config("configs/05_interventions/sd15_sae_steering.yaml", overrides=SAE_STEER_OVERRIDES)
    show_report(str(SAE_STEER_DIR / "report.json"))
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/05_interventions/sd15_sae_steering.yaml --dry-run --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_intervention_prompts.jsonl --override data.sae_checkpoint=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid/sae.pt --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/05_intervention_sae_steering --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override intervention.module=mid_block.attentions.0 --override intervention.target_steps=[24] --override intervention.concept_ids=[290, 497, 1436, 1649, 2233, 4235, 4372, 4957] --override intervention.betas=[2.0]
# dry-run intervention plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/05_interventions/sd15_sae_steering.yaml --override data.prompts_path=/home/jupyter/project/diffusion_attention_analysis_2/prompts/sd15_150_intervention_prompts.jsonl --override data.sae_checkpoint=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/03_sae_mid/sae.pt --override data.output_dir=/home/jupyter/project/diffusion_attention_analysis_2/outputs/sd15_150/05_intervention_sae_steering --override data.max_prompts=150 --override runtime.seed_start=0 --override runtime.num_seeds=1 --override intervention.module=mid_block.attentions.0 --override intervention.target_steps=[24] --override intervention.concept_ids=[290, 497, 1436, 1649, 2233, 4235, 4372, 4957] --override intervention.betas=[2.0]
# 2026-05-10 20:34:56.238901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:20: FutureWarning: `VQEncoderOutput` is deprecated and will be removed in version 0.31. Importing `VQEncoderOutput` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQEncoderOutput`, instead.
#   deprecate("VQEncoderOutput", "0.31", deprecation_message)
# /home/jupyter/.local/lib/python3.10/site-packages/diffusers/models/vq_model.py:25: FutureWarning: `VQModel` is deprecated and will be removed in version 0.31. Importing `VQModel` from `diffusers.models.vq_model` is deprecated and this will be removed in a future version. Please use `from diffusers.models.autoencoders.vq_model import VQModel`, instead.
#   deprecate("VQModel", "0.31", deprecation_message)
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:01,  5.49it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:04<00:13,  2.79s/it]
# Loading pipeline components...:  43%|████▎     | 3/7 [00:04<00:06,  1.59s/it]
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:07<00:05,  1.83s/it]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:25<00:05,  5.66s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:27<00:00,  4.71s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:27<00:00,  3.93s/it]
# SAE steering started:   0%|          | 0/150 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:01<01:31,  1.86s/it]
#   6%|▌         | 3/50 [00:01<00:24,  1.88it/s]
#  10%|█         | 5/50 [00:02<00:13,  3.44it/s]
#  14%|█▍        | 7/50 [00:02<00:08,  5.13it/s]
#  18%|█▊        | 9/50 [00:02<00:05,  6.85it/s]
#  22%|██▏       | 11/50 [00:02<00:04,  8.52it/s]
#  26%|██▌       | 13/50 [00:02<00:03, 10.04it/s]
#  30%|███       | 15/50 [00:02<00:03, 11.31it/s]
#  34%|███▍      | 17/50 [00:02<00:02, 12.39it/s]
#  38%|███▊      | 19/50 [00:03<00:02, 13.25it/s]
#  42%|████▏     | 21/50 [00:03<00:02, 13.92it/s]
#  46%|████▌     | 23/50 [00:03<00:01, 14.44it/s]
#  50%|█████     | 25/50 [00:03<00:02, 10.46it/s]
#  54%|█████▍    | 27/50 [00:03<00:01, 11.64it/s]
#  58%|█████▊    | 29/50 [00:03<00:01, 12.66it/s]
#  62%|██████▏   | 31/50 [00:03<00:01, 13.43it/s]
#  66%|██████▌   | 33/50 [00:04<00:01, 14.03it/s]
#  70%|███████   | 35/50 [00:04<00:01, 14.53it/s]
#  74%|███████▍  | 37/50 [00:04<00:00, 14.86it/s]
#  78%|███████▊  | 39/50 [00:04<00:00, 15.07it/s]
#  82%|████████▏ | 41/50 [00:04<00:00, 15.21it/s]
#  86%|████████▌ | 43/50 [00:04<00:00, 15.35it/s]
#  90%|█████████ | 45/50 [00:04<00:00, 15.47it/s]
#  94%|█████████▍| 47/50 [00:04<00:00, 15.50it/s]
#  98%|█████████▊| 49/50 [00:05<00:00, 15.54it/s]
# 100%|██████████| 50/50 [00:05<00:00,  9.65it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 60.943, 'total': 150, 'current': 1, 'sample_id': 's150_001_dog_grass_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.72it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.22it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.73it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.47it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.86it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.09it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.13it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.25it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.35it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.47it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.51it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.51it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.54it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.62it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.61it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.61it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.60it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.59it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.58it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.58it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.56it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.52it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.54it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.56it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.56it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.25it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 64.475, 'total': 150, 'current': 2, 'sample_id': 's150_002_dog_grass_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.25it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.69it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.41it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.88it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.08it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.14it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.24it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.31it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.30it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.31it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.40it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.42it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.39it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.40it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.45it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.42it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.41it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.42it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.50it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.52it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.52it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.56it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.53it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.53it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.17it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 68.021, 'total': 150, 'current': 3, 'sample_id': 's150_003_dog_grass_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.88it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.48it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.95it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.66it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 15.04it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.18it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.28it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.41it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.47it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.48it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.55it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.63it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.58it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.63it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.64it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.66it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.63it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.63it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.66it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.68it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.60it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.58it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.62it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.68it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.71it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.35it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 71.559, 'total': 150, 'current': 4, 'sample_id': 's150_004_car_street_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.76it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.36it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.91it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.61it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.89it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.20it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.37it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.43it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.54it/s]
#  38%|███▊      | 19/50 [00:01<00:01, 15.55it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.59it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.62it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.56it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.63it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.64it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.65it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.69it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.67it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.65it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.64it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.71it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.75it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.73it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.69it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.66it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.35it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 75.095, 'total': 150, 'current': 5, 'sample_id': 's150_005_car_street_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.91it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.62it/s]
#  10%|█         | 5/50 [00:00<00:03, 14.12it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.77it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 15.08it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.22it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.40it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.50it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.60it/s]
#  38%|███▊      | 19/50 [00:01<00:01, 15.69it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.68it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.63it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.59it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.61it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.59it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.67it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.70it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.69it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.62it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.60it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.62it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.59it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.62it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.67it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.63it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.38it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 78.629, 'total': 150, 'current': 6, 'sample_id': 's150_006_car_street_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.74it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.37it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.83it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.51it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.87it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.13it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.29it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.40it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.45it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.50it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.58it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.66it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.48it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.46it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.45it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.48it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.36it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.40it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.43it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.46it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.49it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.50it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.51it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.47it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.47it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.21it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 82.201, 'total': 150, 'current': 7, 'sample_id': 's150_007_cat_chair_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.74it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.28it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.74it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.46it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.76it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.02it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.15it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.24it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.28it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.31it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.37it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.41it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.48it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.48it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.42it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.43it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.44it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.49it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.57it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.53it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.53it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.58it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.56it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.52it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.18it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 85.789, 'total': 150, 'current': 8, 'sample_id': 's150_008_cat_chair_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.23it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.75it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.36it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.81it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.99it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.13it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.23it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.27it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.35it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.37it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.39it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.38it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.43it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.48it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.52it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.57it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.57it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.56it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.54it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.55it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.54it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.56it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.59it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.19it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 89.374, 'total': 150, 'current': 9, 'sample_id': 's150_009_cat_chair_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.63it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.18it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.70it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.46it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.84it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.02it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.12it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.26it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.35it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.38it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.40it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.48it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.50it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.52it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.55it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.55it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.52it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.57it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.48it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.51it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.57it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.54it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.19it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 92.946, 'total': 150, 'current': 10, 'sample_id': 's150_010_dog_bicycle_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.75it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.36it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.86it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.53it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.92it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.15it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.31it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.35it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.43it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.47it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.48it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.55it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.52it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.49it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.44it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.53it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.53it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.55it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.52it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.55it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.49it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.49it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.49it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.23it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 96.509, 'total': 150, 'current': 11, 'sample_id': 's150_011_dog_bicycle_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.27it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.71it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.49it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.85it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.06it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.19it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.29it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.32it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.41it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.38it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.43it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.44it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.50it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.48it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.48it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.47it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.48it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.50it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.53it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.52it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.60it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.65it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.62it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.21it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 100.084, 'total': 150, 'current': 12, 'sample_id': 's150_012_dog_bicycle_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.65it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.29it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.79it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.52it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.82it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.97it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.14it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.30it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.43it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.52it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.42it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.35it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.36it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.43it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.49it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.46it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.51it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.53it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.55it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.56it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.56it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.59it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.63it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.60it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.21it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 103.668, 'total': 150, 'current': 13, 'sample_id': 's150_013_cup_book_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.78it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.32it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.78it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.51it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.91it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.14it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.27it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.31it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.37it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.46it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.50it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.50it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.51it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.51it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.55it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.49it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.50it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.55it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.60it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.61it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.63it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.55it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.57it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.57it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.25it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 107.237, 'total': 150, 'current': 14, 'sample_id': 's150_014_cup_book_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.32it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.83it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.47it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.82it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.10it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.24it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.34it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.42it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.44it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.45it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.47it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.41it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.47it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.53it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.49it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.62it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.56it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.56it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.60it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.60it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.54it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.49it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.22it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 110.791, 'total': 150, 'current': 15, 'sample_id': 's150_015_cup_book_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.75it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.27it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.70it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.41it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.76it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.00it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.16it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.30it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.42it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.45it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.47it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.50it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.42it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.39it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.44it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.44it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.45it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.45it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.44it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.39it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.43it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.43it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.41it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.51it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.16it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 114.399, 'total': 150, 'current': 16, 'sample_id': 's150_016_vase_flower_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.77it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.30it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.77it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.45it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.86it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.11it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.25it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.35it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.41it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.46it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.46it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.42it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.39it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.40it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.39it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.45it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.47it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.52it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.52it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.57it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.54it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.48it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.50it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.46it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.19it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 117.993, 'total': 150, 'current': 17, 'sample_id': 's150_017_vase_flower_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.80it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.33it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.73it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.45it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.82it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.11it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.27it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.35it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.44it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.38it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.40it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.45it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.44it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.45it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.47it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.46it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.45it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.48it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.54it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.59it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.61it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.63it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.60it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.56it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.22it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 121.546, 'total': 150, 'current': 18, 'sample_id': 's150_018_vase_flower_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.70it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.31it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.78it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.53it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.92it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.12it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.28it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.42it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.49it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.49it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.51it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.54it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.50it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.48it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.52it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.56it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.59it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.64it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.62it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.60it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.63it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.60it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.66it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.64it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.57it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.28it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 125.127, 'total': 150, 'current': 19, 'sample_id': 's150_019_person_umbrella_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.74it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.29it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.80it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.49it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.85it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.04it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.13it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.29it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.39it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.46it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.45it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.49it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.49it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.55it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.56it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.57it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.59it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.60it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.57it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.54it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.59it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.59it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.61it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.59it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.24it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 128.705, 'total': 150, 'current': 20, 'sample_id': 's150_020_person_umbrella_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.27it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.79it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.52it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.89it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.10it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.31it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.37it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.46it/s]
#  38%|███▊      | 19/50 [00:01<00:01, 15.51it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.58it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.55it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.56it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.56it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.55it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.56it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.50it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.55it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.54it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.49it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.48it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.50it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.24it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 132.265, 'total': 150, 'current': 21, 'sample_id': 's150_021_person_umbrella_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.75it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.41it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.85it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.51it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.78it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.00it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.14it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.18it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.26it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.41it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.47it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.47it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.49it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.55it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.58it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.63it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.65it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.65it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.61it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.64it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.62it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.66it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.65it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.63it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.26it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 135.829, 'total': 150, 'current': 22, 'sample_id': 's150_022_robot_bench_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.77it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.31it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.82it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.55it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.96it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.20it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.35it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.36it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.43it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.50it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.57it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.57it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.56it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.53it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.54it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.54it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.58it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.58it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.59it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.59it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.56it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.50it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.52it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.27it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 139.403, 'total': 150, 'current': 23, 'sample_id': 's150_023_robot_bench_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.76it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.37it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.76it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.48it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.88it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.07it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.16it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.24it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.28it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.33it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.40it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.39it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.43it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.44it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.46it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.45it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.42it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.47it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.48it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.46it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.46it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.41it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.43it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.15it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 142.981, 'total': 150, 'current': 24, 'sample_id': 's150_024_robot_bench_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.19it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.67it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.38it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.75it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.01it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.15it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.25it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.44it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.43it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.40it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.42it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.46it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.48it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.47it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.51it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.56it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.56it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.51it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.48it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.49it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.48it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.17it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 146.55, 'total': 150, 'current': 25, 'sample_id': 's150_025_bicycle_tree_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.60it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.17it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.67it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.39it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.77it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.01it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.19it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.32it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.38it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.36it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.45it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.52it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.60it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.60it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.63it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.57it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.53it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.54it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.54it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.61it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.59it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.63it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.61it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.23it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 150.092, 'total': 150, 'current': 26, 'sample_id': 's150_026_bicycle_tree_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.64it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.26it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.78it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.47it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.84it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.08it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.21it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.26it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.42it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.46it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.50it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.45it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.52it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.54it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.63it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.66it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.65it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.65it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.65it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.63it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.62it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.61it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.62it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.26it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 153.624, 'total': 150, 'current': 27, 'sample_id': 's150_027_bicycle_tree_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.77it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.35it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.82it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.53it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.91it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.21it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.34it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.41it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.39it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.38it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.45it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.43it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.45it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.47it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.46it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.40it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.39it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.41it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.40it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.45it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.51it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.55it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.47it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.19it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 157.187, 'total': 150, 'current': 28, 'sample_id': 's150_028_dog_bench_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.68it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.23it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.76it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.51it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.88it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.03it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.20it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.32it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.35it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.42it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.47it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.47it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.45it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.47it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.51it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.56it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.57it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.64it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.67it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.66it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.59it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.58it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.57it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.52it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.54it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.24it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 160.752, 'total': 150, 'current': 29, 'sample_id': 's150_029_dog_bench_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.79it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.39it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.81it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.44it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.85it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.09it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.15it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.22it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.31it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.41it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.46it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.50it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.51it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.52it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.53it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.57it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.51it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.45it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.46it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.41it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.41it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.42it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.37it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.40it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.36it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.16it/s]
# ...
#  14%|█▍        | 7/50 [00:00<00:02, 14.42it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.77it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.02it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.10it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.14it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.23it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.35it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.47it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.52it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.54it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.58it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.56it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.54it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.50it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.40it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.45it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.50it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.52it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.51it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.52it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.49it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.53it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.19it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 557.447, 'total': 150, 'current': 140, 'sample_id': 's150_140_camera_tripod_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.75it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.34it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.72it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.38it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.76it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.00it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.16it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.32it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.39it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.46it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.49it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.41it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.42it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.47it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.47it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.52it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.47it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.50it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.51it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.52it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.51it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.46it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.42it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.34it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.32it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.15it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 561.022, 'total': 150, 'current': 141, 'sample_id': 's150_141_camera_tripod_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.60it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.16it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.52it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.21it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.55it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.81it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 14.92it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.01it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.02it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.12it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.18it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.23it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.26it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.27it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.31it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.33it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.32it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.31it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.36it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.35it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.44it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.46it/s]
#  90%|█████████ | 45/50 [00:03<00:00, 15.51it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.51it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.51it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.04it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 564.677, 'total': 150, 'current': 142, 'sample_id': 's150_142_candle_shelf_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.68it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.15it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.59it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.41it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.84it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.08it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.27it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.36it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.42it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.44it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.44it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.43it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.41it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.49it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.42it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.45it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.45it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.47it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.49it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.49it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.49it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.47it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.39it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.38it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.36it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.15it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 568.293, 'total': 150, 'current': 143, 'sample_id': 's150_143_candle_shelf_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.71it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.32it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.78it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.48it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.79it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.05it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.21it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.28it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.34it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.40it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.45it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.46it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.41it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.34it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.35it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.36it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.40it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.43it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.42it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.40it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.37it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.42it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.47it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.46it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.15it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 571.882, 'total': 150, 'current': 144, 'sample_id': 's150_144_candle_shelf_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.62it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.23it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.77it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.49it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.86it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.12it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.27it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.30it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.37it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.42it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.49it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.52it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.47it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.49it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.50it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.56it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.56it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.54it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.57it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.57it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.59it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.61it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.61it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.56it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.58it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.24it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 575.45, 'total': 150, 'current': 145, 'sample_id': 's150_145_fish_bowl_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.75it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.23it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.71it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.33it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.77it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.00it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.13it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.29it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.32it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.40it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.42it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.40it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.42it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.46it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.42it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.43it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.48it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.43it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.40it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.39it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.48it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.49it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.54it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.61it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.17it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 579.011, 'total': 150, 'current': 146, 'sample_id': 's150_146_fish_bowl_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.77it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.21it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.70it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.37it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.75it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.95it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.10it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.19it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.23it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.25it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.25it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.22it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.22it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.29it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.27it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.37it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.42it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.44it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.46it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.47it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.51it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.50it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.50it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.54it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.51it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.12it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 582.585, 'total': 150, 'current': 147, 'sample_id': 's150_147_fish_bowl_detailed_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.73it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.27it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.60it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.34it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.73it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.95it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.09it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.26it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.33it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.33it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.37it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.42it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.40it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.46it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.50it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.50it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.48it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.41it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.42it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.42it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.44it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.44it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.46it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.50it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.48it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.15it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 586.19, 'total': 150, 'current': 148, 'sample_id': 's150_148_plant_window_photo_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.71it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.28it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.72it/s]
#  14%|█▍        | 7/50 [00:00<00:02, 14.38it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.83it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 15.08it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.18it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.30it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.36it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.38it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.40it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.41it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.39it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.35it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.36it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.40it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.40it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.45it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.47it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.49it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.49it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.47it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.45it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.48it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.49it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.16it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 589.803, 'total': 150, 'current': 149, 'sample_id': 's150_149_plant_window_clear_seed_0000_beta_2'}
#   0%|          | 0/50 [00:00<?, ?it/s]
#   2%|▏         | 1/50 [00:00<00:06,  7.69it/s]
#   6%|▌         | 3/50 [00:00<00:03, 12.27it/s]
#  10%|█         | 5/50 [00:00<00:03, 13.71it/s]
#  14%|█▍        | 7/50 [00:00<00:03, 14.31it/s]
#  18%|█▊        | 9/50 [00:00<00:02, 14.64it/s]
#  22%|██▏       | 11/50 [00:00<00:02, 14.90it/s]
#  26%|██▌       | 13/50 [00:00<00:02, 15.08it/s]
#  30%|███       | 15/50 [00:01<00:02, 15.21it/s]
#  34%|███▍      | 17/50 [00:01<00:02, 15.24it/s]
#  38%|███▊      | 19/50 [00:01<00:02, 15.28it/s]
#  42%|████▏     | 21/50 [00:01<00:01, 15.41it/s]
#  46%|████▌     | 23/50 [00:01<00:01, 15.41it/s]
#  50%|█████     | 25/50 [00:01<00:01, 15.43it/s]
#  54%|█████▍    | 27/50 [00:01<00:01, 15.47it/s]
#  58%|█████▊    | 29/50 [00:01<00:01, 15.49it/s]
#  62%|██████▏   | 31/50 [00:02<00:01, 15.42it/s]
#  66%|██████▌   | 33/50 [00:02<00:01, 15.42it/s]
#  70%|███████   | 35/50 [00:02<00:00, 15.44it/s]
#  74%|███████▍  | 37/50 [00:02<00:00, 15.44it/s]
#  78%|███████▊  | 39/50 [00:02<00:00, 15.42it/s]
#  82%|████████▏ | 41/50 [00:02<00:00, 15.44it/s]
#  86%|████████▌ | 43/50 [00:02<00:00, 15.46it/s]
#  90%|█████████ | 45/50 [00:02<00:00, 15.44it/s]
#  94%|█████████▍| 47/50 [00:03<00:00, 15.44it/s]
#  98%|█████████▊| 49/50 [00:03<00:00, 15.40it/s]
# 100%|██████████| 50/50 [00:03<00:00, 15.11it/s]
# SAE steering generated {'stage_id': '05_intervention_sd15_sae_steering', 'time_sec': 593.385, 'total': 150, 'current': 150, 'sample_id': 's150_150_plant_window_detailed_seed_0000_beta_2'}
# SAE steering finished

# %% [markdown]
# ## Final numeric summary

# %%
report_paths = {
    "01_capture": CAPTURE_DIR / "report.json",
    "02_masks": MASK_DIR / "report.json",
    "02_attention_localization": LOC_DIR / "report.json",
    "03_sae": SAE_DIR / "report.json",
    "04_concept_dictionary": CONCEPT_DIR / "report.json",
    "05_map_reweight": MAP_DIR / "report.json",
    "05_sae_steering": SAE_STEER_DIR / "report.json",
}

summary_rows = []
for stage, path in report_paths.items():
    row = {"stage": stage, "report_path": str(path), "exists": path.exists()}
    if path.exists():
        data = json.loads(path.read_text(encoding="utf-8"))
        row.update({
            "status": data.get("status"),
            "samples": data.get("samples"),
            "rows": data.get("rows"),
            "labels": data.get("labels"),
            "masks": data.get("masks"),
        })
    summary_rows.append(row)

display(pd.DataFrame(summary_rows))
# Out:
#                        stage  ...  masks
# 0                 01_capture  ...    NaN
# 1                   02_masks  ...  315.0
# 2  02_attention_localization  ...    NaN
# 3                     03_sae  ...    NaN
# 4      04_concept_dictionary  ...    NaN
# 5            05_map_reweight  ...    NaN
# 6            05_sae_steering  ...    NaN
#
# [7 rows x 8 columns]
