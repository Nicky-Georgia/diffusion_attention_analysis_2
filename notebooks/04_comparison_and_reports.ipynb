# %% [markdown]
# # 04 — Comparison and reports
#
# The comparison configs aggregate stage reports. SD3 Medium and SANA are explicitly marked as `pilot_only`.

# %%
from pathlib import Path
import os, sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.environ["PYTHONPATH"] = str(PROJECT_ROOT / "src") + os.pathsep + os.environ.get("PYTHONPATH", "")
print("PROJECT_ROOT =", PROJECT_ROOT)

from diffusion_attention_analysis_v2.notebook_runner import run_config, run_suite, show_report

# %% [markdown]
# ## UNet main comparison

# %%
run_config("configs/06_comparison/unet_main_comparison.yaml")
show_report("outputs/comparison/unet_main/report.json")

# %%
import pandas as pd
from pathlib import Path
path = PROJECT_ROOT / "outputs/comparison/unet_main/comparison_summary.csv"
if path.exists():
    display(pd.read_csv(path))
else:
    print("Missing", path)

# %% [markdown]
# ## All-model pilot summary

# %%
run_config("configs/06_comparison/all_models_pilot_summary.yaml")
show_report("outputs/comparison/all_models_pilot/report.json")

# %%
path = PROJECT_ROOT / "outputs/comparison/all_models_pilot/comparison_summary.csv"
if path.exists():
    display(pd.read_csv(path))
else:
    print("Missing", path)
