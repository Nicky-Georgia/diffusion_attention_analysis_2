# %% [markdown]
# # 00 — Environment and config check
#
# Run this notebook first. It performs dry runs only, so it does not download models or allocate GPU memory.

# %%
from pathlib import Path
import os, sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.environ["PYTHONPATH"] = str(PROJECT_ROOT / "src") + os.pathsep + os.environ.get("PYTHONPATH", "")
print("PROJECT_ROOT =", PROJECT_ROOT)

from diffusion_attention_analysis_v2.notebook_runner import run_config, run_suite, show_report
# Out:
# PROJECT_ROOT = /home/jupyter/project/diffusion_attention_analysis_2

# %%
import torch, yaml
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("gpu:", torch.cuda.get_device_name(0))
# Out:
# torch: 2.0.1+cu118
# cuda available: True
# gpu: Tesla V100-PCIE-32GB

# %% [markdown]
# ## Dry-run key configs
#
# The progress bars below confirm that the config executor starts correctly and writes plans.

# %%
run_config("configs/01_capture/sd15_full.yaml", dry_run=True)
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sd15_full.yaml --dry-run
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# {'status': 'dry_run',
#  'plan': {'stage': {'id': '01_capture_sd15_full',
#    'name': 'capture',
#    'description': 'Full UNet baseline: generate images and capture cross-attention, residual updates, and latents.',
#    'claim_level': 'main',
#    'enabled': True},
#   'model': {'name': 'sd15',
#    'family': 'unet',
#    'pipeline_class': 'auto_t2i',
#    'model_id': 'runwayml/stable-diffusion-v1-5'},
#   'data': {'prompts_path': 'prompts/pilot_prompts.jsonl',
#    'max_prompts': 1000,
#    'output_dir': 'outputs/sd15/01_capture'},
#   'expected_artifacts': ['samples/*/image.png',
#    'captures/*/attention/step_*/',
#    'captures/*/activations/step_*/',
#    'manifest.json'],
#   'logic_check': {'main_question': 'Which internal states appear at early/middle/late denoising steps?',
#    'unet_models': 'record cross-attention maps, latents, and selected residual/activation updates',
#    'transformer_models': 'shortened: selected block-output hooks only; no default attention-probability sweep'}}}

# %%
run_config("configs/01_capture/sdxl_transfer.yaml", dry_run=True)
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sdxl_transfer.yaml --dry-run
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# {'status': 'dry_run',
#  'plan': {'stage': {'id': '01_capture_sdxl_transfer',
#    'name': 'capture',
#    'description': 'SDXL transfer capture on matched subset; not a second full baseline.',
#    'claim_level': 'transfer',
#    'enabled': True},
#   'model': {'name': 'sdxl',
#    'family': 'unet',
#    'pipeline_class': 'auto_t2i',
#    'model_id': 'stabilityai/stable-diffusion-xl-base-1.0'},
#   'data': {'prompts_path': 'prompts/pilot_prompts.jsonl',
#    'max_prompts': 250,
#    'output_dir': 'outputs/sdxl/01_capture'},
#   'expected_artifacts': ['samples/*/image.png',
#    'captures/*/attention/step_*/',
#    'captures/*/activations/step_*/'],
#   'logic_check': {'main_question': 'Which internal states appear at early/middle/late denoising steps?',
#    'unet_models': 'record cross-attention maps, latents, and selected residual/activation updates',
#    'transformer_models': 'shortened: selected block-output hooks only; no default attention-probability sweep'}}}

# %%
run_config("configs/01_capture/sd3_medium_short.yaml", dry_run=True)
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sd3_medium_short.yaml --dry-run
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# {'status': 'dry_run',
#  'plan': {'stage': {'id': '01_capture_sd3_medium_short',
#    'name': 'capture',
#    'description': 'Short transformer pilot for SD3 Medium: image generation plus selected transformer-block activations only.',
#    'claim_level': 'pilot_only',
#    'enabled': True},
#   'model': {'name': 'sd3_medium',
#    'family': 'transformer',
#    'pipeline_class': 'sd3',
#    'model_id': 'stabilityai/stable-diffusion-3-medium-diffusers'},
#   'data': {'prompts_path': 'prompts/pilot_prompts.jsonl',
#    'max_prompts': 64,
#    'output_dir': 'outputs/sd3_medium/01_capture'},
#   'expected_artifacts': ['samples/*/image.png',
#    'captures/*/activations/step_*/'],
#   'logic_check': {'main_question': 'Which internal states appear at early/middle/late denoising steps?',
#    'unet_models': 'record cross-attention maps, latents, and selected residual/activation updates',
#    'transformer_models': 'shortened: selected block-output hooks only; no default attention-probability sweep'}}}

# %%
run_config("configs/01_capture/sana_short.yaml", dry_run=True)
# Out:
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sana_short.yaml --dry-run
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# {'status': 'dry_run',
#  'plan': {'stage': {'id': '01_capture_sana_short',
#    'name': 'capture',
#    'description': 'Short transformer pilot for SANA: image generation plus selected block activations only.',
#    'claim_level': 'pilot_only',
#    'enabled': True},
#   'model': {'name': 'sana',
#    'family': 'transformer',
#    'pipeline_class': 'sana',
#    'model_id': 'Efficient-Large-Model/Sana_1600M_1024px_BF16_diffusers'},
#   'data': {'prompts_path': 'prompts/pilot_prompts.jsonl',
#    'max_prompts': 64,
#    'output_dir': 'outputs/sana/01_capture'},
#   'expected_artifacts': ['samples/*/image.png',
#    'captures/*/activations/step_*/'],
#   'logic_check': {'main_question': 'Which internal states appear at early/middle/late denoising steps?',
#    'unet_models': 'record cross-attention maps, latents, and selected residual/activation updates',
#    'transformer_models': 'shortened: selected block-output hooks only; no default attention-probability sweep'}}}

# %% [markdown]
# ## Dry-run a suite

# %%
configs = [
    "configs/01_capture/sd15_full.yaml",
    "configs/02_attention_localization/sd15_full.yaml",
    "configs/03_sae_training/sd15_full.yaml",
    "configs/04_concept_dictionary/sd15_full.yaml",
    "configs/05_interventions/sd15_map_reweight.yaml",
    "configs/06_comparison/unet_main_comparison.yaml",
]
run_suite(configs, dry_run=True)
# Out:
# === configs/01_capture/sd15_full.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/01_capture/sd15_full.yaml --dry-run
# dry-run capture plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# === configs/02_attention_localization/sd15_full.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/02_attention_localization/sd15_full.yaml --dry-run
# dry-run attention_localization plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# === configs/03_sae_training/sd15_full.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/03_sae_training/sd15_full.yaml --dry-run
# dry-run sae_training plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# === configs/04_concept_dictionary/sd15_full.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/04_concept_dictionary/sd15_full.yaml --dry-run
# dry-run concept_dictionary plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# === configs/05_interventions/sd15_map_reweight.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/05_interventions/sd15_map_reweight.yaml --dry-run
# dry-run intervention plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# === configs/06_comparison/unet_main_comparison.yaml ===
# $ /usr/local/bin/python3 -m diffusion_attention_analysis_v2.cli.run_stage --config configs/06_comparison/unet_main_comparison.yaml --dry-run
# dry-run comparison plan:   0%|          | 0/1 [00:00<?, ?it/s]
# dry-run complete
# [{'status': 'dry_run',
#   'plan': {'stage': {'id': '01_capture_sd15_full',
#     'name': 'capture',
#     'description': 'Full UNet baseline: generate images and capture cross-attention, residual updates, and latents.',
#     'claim_level': 'main',
#     'enabled': True},
#    'model': {'name': 'sd15',
#     'family': 'unet',
#     'pipeline_class': 'auto_t2i',
#     'model_id': 'runwayml/stable-diffusion-v1-5'},
#    'data': {'prompts_path': 'prompts/pilot_prompts.jsonl',
#     'max_prompts': 1000,
#     'output_dir': 'outputs/sd15/01_capture'},
#    'expected_artifacts': ['samples/*/image.png',
#     'captures/*/attention/step_*/',
#     'captures/*/activations/step_*/',
#     'manifest.json'],
#    'logic_check': {'main_question': 'Which internal states appear at early/middle/late denoising steps?',
#     'unet_models': 'record cross-attention maps, latents, and selected residual/activation updates',
#     'transformer_models': 'shortened: selected block-output hooks only; no default attention-probability sweep'}}},
#  {'status': 'dry_run',
#   'plan': {'stage': {'id': '02_attention_localization_sd15_full',
#     'name': 'attention_localization',
#     'description': 'Evaluate whether SD1.5 cross-attention maps align with object masks.',
#     'claim_level': 'main',
#     'enabled': True},
#    'model': {'name': 'sd15',
#     'family': 'unet',
#     'pipeline_class': None,
#     'model_id': None},
#    'data': {'prompts_path': None,
#     'max_prompts': None,
#     'output_dir': 'outputs/sd15/02_attention_localization'},
#    'expected_artifacts': ['attention_localization_rows.csv',
#     'attention_localization_by_step.csv',
#     'report.json'],
#    'logic_check': {'question': 'Do cross-attention maps align with object masks?',
#     'guardrail': 'Missing annotations/token matches are reported separately, not silently counted as failures.'}}},
#  {'status': 'dry_run',
#   'plan': {'stage': {'id': '03_sae_training_sd15_full',
#     'name': 'sae_training',
#     'description': 'Main Top-K SAE on SD1.5 middle-time residual activations.',
#     'claim_level': 'main',
#     'enabled': True},
#    'model': {'name': 'sd15',
#     'family': 'unet',
#     'pipeline_class': None,
#     'model_id': None},
#    'data': {'prompts_path': None,
#     'max_prompts': None,
#     'output_dir': 'outputs/sd15/03_sae_mid'},
#    'expected_artifacts': ['sae.pt', 'history.json', 'report.json'],
#    'logic_check': {'question': 'Can dense denoising activations be decomposed into sparse reusable features?',
#     'main_path': 'SD1.5 full SAE; SDXL reduced transfer SAE',
#     'transformer_path': 'short pilot SAE only; not the basis for full causal claims'}}},
#  {'status': 'dry_run',
#   'plan': {'stage': {'id': '04_concept_dictionary_sd15_full',
#     'name': 'concept_dictionary',
#     'description': 'Build SD1.5 SAE feature dictionary from mask-aligned inside-vs-outside contrast.',
#     'claim_level': 'main',
#     'enabled': True},
#    'model': {'name': 'sd15',
#     'family': 'unet',
#     'pipeline_class': None,
#     'model_id': None},
#    'data': {'prompts_path': None,
#     'max_prompts': None,
#     'output_dir': 'outputs/sd15/04_concept_dictionary'},
#    'expected_artifacts': ['concept_dictionary.json',
#     'concept_dictionary.csv',
#     'report.json'],
#    'logic_check': {'question': 'Which SAE features align with object masks?',
#     'control': 'features are ranked by inside-vs-outside activation contrast, not cherry-picked images',
#     'scope': 'main for SD1.5/SDXL; disabled for transformer pilots in default configs'}}},
#  {'status': 'dry_run',
#   'plan': {'stage': {'id': '05_intervention_sd15_map_reweight',
#     'name': 'intervention',
#     'description': 'SD1.5 map-level causal probe: reweight cross-attention for target token in target region.',
#     'claim_level': 'main',
#     'enabled': True},
#    'model': {'name': 'sd15',
#     'family': 'unet',
#     'pipeline_class': 'auto_t2i',
#     'model_id': 'runwayml/stable-diffusion-v1-5'},
#    'data': {'prompts_path': 'prompts/intervention_prompts.jsonl',
#     'max_prompts': 40,
#     'output_dir': 'outputs/sd15/05_intervention_map_reweight'},
#    'expected_artifacts': ['samples/*/intervention.png',
#     'captures/*/attention/step_*/',
#     'report.json'],
#    'logic_check': {'question': 'Does changing target-token cross-attention at selected steps alter the intended image region?',
#     'guardrail': 'same-seed intervention outputs must be compared against baseline outputs and off-target drift later'}}},
#  {'status': 'dry_run',
#   'plan': {'stage': {'id': '06_comparison_unet_main',
#     'name': 'comparison',
#     'description': 'Quantitative comparison of main UNet results: SD1.5 full baseline vs SDXL transfer.',
#     'claim_level': 'comparison',
#     'enabled': True},
#    'model': {'name': 'comparison_unet',
#     'family': 'comparison',
#     'pipeline_class': None,
#     'model_id': None},
#    'data': {'prompts_path': None,
#     'max_prompts': None,
#     'output_dir': 'outputs/comparison/unet_main'},
#    'expected_artifacts': ['comparison_summary.csv', 'report.json'],
#    'logic_check': {'question': 'What can be compared fairly across models and what must stay marked as pilot-only?',
#     'rule': 'SD3 Medium and SANA are not treated as symmetric raw-attention benchmarks in default configs.'}}}]
